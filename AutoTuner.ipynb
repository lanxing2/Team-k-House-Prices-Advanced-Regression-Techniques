# %%
# load data
import pandas as pd
import numpy as np
from pandas import DataFrame
base_path='D:/kaggle/regression/'
all_data=DataFrame.from_csv(base_path+'cleaned_train.csv',index_col='Id')
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Columns: 263 entries, LotFrontage to SaleCondition__Partial
# dtypes: float64(231), int64(32)
# memory usage: 2.9 MB

# %%
all_id=all_data.index
all_y=all_data['SalePrice']
all_x=all_data.drop(['SalePrice'],axis=1)
all_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Columns: 262 entries, LotFrontage to SaleCondition__Partial
# dtypes: float64(231), int64(31)
# memory usage: 2.9 MB

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(all_x, all_y, test_size=0.2, random_state=42)

# %%
def reportParams(best_parameters, score):
    print('score:', score)
    for param_name in sorted(best_parameters.keys()):
        print("%s: %r" % (param_name, best_parameters[param_name]))

# %%
from sklearn.metrics import mean_squared_error

def rmse_log_error(predict,reality):
    predict_log=np.log(predict)
    reality_log=np.log(reality)
    mse=mean_squared_error(reality_log, predict_log)
    rmse=np.sqrt(mse)
    return rmse

# %%
def find_value_in_array(arr,value):
    for i in range(len(arr)):
        v=arr[i]
        if abs(v - value) <= 1e-5:
            return i
    return -1

# %%
arr=[0.001,0.5,1.0,8]
find_value_in_array(arr,8)
# Out:
# 3

# %%
def remove_dup(arr):
    return np.unique(arr)

# %%
remove_dup([1,1,2,3,4,4,4,5,6,8,6,])
# Out:
# array([1, 2, 3, 4, 5, 6, 8])

# %%
def exp_space(start,end,base):
    exp_arr=np.linspace(start,end,6)
    return [base**x for x in exp_arr]

# %%
exp_space(-4,4,2)
# Out:
# [0.0625,
#  0.18946457081379978,
#  0.57434917749851755,
#  1.7411011265922491,
#  5.2780316430915786,
#  16.0]

# %%
from sklearn.grid_search import GridSearchCV
import math

def auto_param_search(regressor,search_params,iterations, train_X, train_y, test_X, test_y):
    print iterations,' iterations of search for regressor '
    print type(regressor)
    print 'Starting param range is ',params
    
    # Define some parameters
    split=6 # must > 2
    cv_num=5
    
    for i in range(iterations):
        print 'This iteration is for params ',search_params
        
        # Finer grind the range
        params_to_try={}
        for k in search_params.keys():
            print 'Grinding param ',k
            start=search_params[k]['start']
            end=search_params[k]['end']
            # Check if start is just end
            if start==end:
                params_to_try[k]=[start]
            else:
                # linear space if not specified
                if 'dist' not in search_params[k].keys():
                    search_params[k]['dist']='linear'
                # Check the wanted distribution of param
                dist=search_params[k]['dist']
                if dist == 'linear':
                    params_to_try[k]=np.linspace(start,end,split)
                elif dist == 'exp':
                    params_to_try[k] = np.logspace(start, end, num=split, base=2.0) # Use 2 as base
                else:
                    print "Error: Expected type for param ',k,' is not recognized. Cannot proceed!"
                    print "Options: 'linear' or 'exp'"
                    return
            print 
        print 'Grinded params to ',params_to_try
        
        # Find int parameters and round them
        for k in search_params.keys():
            if search_params[k]['type']=='int':
                print 'Rounding param ',k, 'with list ',params_to_try[k]
                params_to_try[k]=[int(round(x)) for x in params_to_try[k]]
                
                # Remove dup
                params_to_try[k]=remove_dup(params_to_try[k])
                
                print 'Now rounded to ',params_to_try[k]
        print 'Grinded params are rounded to ',params_to_try
                
        # Exhaustive search
        gs = GridSearchCV(regressor, params_to_try,scoring='neg_mean_squared_error',cv=cv_num,verbose=2)
        gs.fit(train_X, train_y)
        print 'Report scores'
        print gs.grid_scores_
        print("Report best params")
        best_parameters, score, _ = max(gs.grid_scores_, key=lambda x: x[1])
        reportParams(best_parameters, score)

        # Get the best regressor
        best=gs.best_estimator_
        print 'Params for best estimator are ',best.get_params()
        best.fit(X_train,y_train)
        print 'Now predict'
        best_predict=best.predict(X_test)
        #print 'Predicted values are ',best_predict
        print('RMSE {score}'.format(score=rmse_log_error(y_test, best_predict)))

        # Calculate stats
        predict_series=pd.Series(best_predict)
        print "Std: ",np.std(predict_series)," Mean: ",np.mean(predict_series)
        print 'Min: ',min(predict_series),' Max: ',max(predict_series)
        
        # Update the new range
        for k in best_parameters.keys():
            print 'Update param ',k
            
            # If the start and end meet, no need to update really
            if len(params_to_try[k])==1:
                print 'The start and end meet for param ',k,'. No need to update.'
                continue
            
            # Check the distribution of the param
            param_type=search_params[k]['dist']
            if param_type=='exp':
                start=search_params[k]['start']
                end=search_params[k]['end']
                exp_arr=np.linspace(start,end,split)
                step = exp_arr[1]-exp_arr[0]
                print 'Param ',k,' has exponential distribution. One step is ',step
            else: # linear distribution
                step=params_to_try[k][1]-params_to_try[k][0]
                print 'Param ',k,' has linear distribution. One step is ',step
            
            # Find the best param
            v=best_parameters[k]
            print 'Finding best param for value ',v
            if param_type == 'exp':
                on_exp=math.log(v,2)
                print 'Convert exp back to power ',v,'->',on_exp
                best_index=find_value_in_array(params_to_try[k],on_exp)
            else:
                best_index=find_value_in_array(params_to_try[k],v)
            print 'Best index is ',best_index
            
            # The best param happens to be on the edge
            if best_index == 0:
                print 'Arrived at start of search range ',v
                search_params[k]['start']=v
                target_idx=max(len(params_to_try[k])-1,best_index+2)
                search_params[k]['end']=params_to_try[k][target_idx]
            elif best_index == split-1:
                print 'Arrived at end of search range ',v
                step=(params[k]['end']-params[k]['start'])/split
                #print 'Go one step forward for ',step
                target_idx=min(0,best_index-2)
                search_params[k]['start']=params_to_try[k][target_idx]
                search_params[k]['end']=v
            
            # The param is in the middle of range
            else:
                print 'The param falls in the middle of range'
                if param_type == 'exp':
                    on_exp=math.log(v,2)
                    search_params[k]['start']=on_exp-step
                    search_params[k]['end']=on_exp+step
                else:
                    search_params[k]['start']=v-step
                    search_params[k]['end']=v+step                
            
        print 'Params updated: ',search_params
        print 'Go to next turn'

# %%
from sklearn.ensemble import RandomForestRegressor

print "Random forest with mse"
params={
    'n_estimators':{
        'start':1,
        'end':7,
        'type':'int',
        'dist':'exp'
    },
    'max_features':{
        'start':1.0,
        'end':1.0,
        'type':'float',
        'dist':'linear'
    },
    'max_depth':{
        'start':10,
        'end':10,
        'type':'int',
        'dist':'linear'
    },
    
}
rfc = RandomForestRegressor(criterion='mse', n_jobs=-1,random_state=42)

auto_param_search(rfc,params,3, X_train, y_train, X_test, y_test)
# Out:
# Random forest with mse
# 3  iterations of search for regressor
# <class 'sklearn.ensemble.forest.RandomForestRegressor'>
# Starting param range is  {'n_estimators': {'start': 1, 'end': 7, 'dist': 'exp', 'type': 'int'}, 'max_features': {'start': 1.0, 'end': 1.0, 'dist': 'linear', 'type': 'float'}, 'max_depth': {'start': 10, 'end': 10, 'dist': 'linear', 'type': 'int'}}
# This iteration is for params  {'n_estimators': {'start': 1, 'end': 7, 'dist': 'exp', 'type': 'int'}, 'max_features': {'start': 1.0, 'end': 1.0, 'dist': 'linear', 'type': 'float'}, 'max_depth': {'start': 10, 'end': 10, 'dist': 'linear', 'type': 'int'}}
# Grinding param  n_estimators
#
# Grinding param  max_features
#
# Grinding param  max_depth
#
# Grinded params to  {'n_estimators': array([   2.        ,    4.59479342,   10.55606329,   24.25146506,
#          55.71523605,  128.        ]), 'max_features': [1.0], 'max_depth': [10]}
# Rounding param  n_estimators with list  [   2.            4.59479342   10.55606329   24.25146506   55.71523605
#   128.        ]
# Now rounded to  [  2   5  11  24  56 128]
# Rounding param  max_depth with list  [10]
# Now rounded to  [10]
# Grinded params are rounded to  {'n_estimators': array([  2,   5,  11,  24,  56, 128]), 'max_features': [1.0], 'max_depth': array([10])}
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] max_features=1.0, n_estimators=2, max_depth=10 ..................
# [CV] ......... max_features=1.0, n_estimators=2, max_depth=10 -   0.2s
# [CV] max_features=1.0, n_estimators=2, max_depth=10 ..................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [CV] ......... max_features=1.0, n_estimators=2, max_depth=10 -   0.2s
# [CV] max_features=1.0, n_estimators=2, max_depth=10 ..................
# [CV] ......... max_features=1.0, n_estimators=2, max_depth=10 -   0.2s
# [CV] max_features=1.0, n_estimators=2, max_depth=10 ..................
# [CV] ......... max_features=1.0, n_estimators=2, max_depth=10 -   0.2s
# [CV] max_features=1.0, n_estimators=2, max_depth=10 ..................
# [CV] ......... max_features=1.0, n_estimators=2, max_depth=10 -   0.2s
# [CV] max_features=1.0, n_estimators=5, max_depth=10 ..................
# [CV] ......... max_features=1.0, n_estimators=5, max_depth=10 -   0.2s
# [CV] max_features=1.0, n_estimators=5, max_depth=10 ..................
# [CV] ......... max_features=1.0, n_estimators=5, max_depth=10 -   0.2s
# [CV] max_features=1.0, n_estimators=5, max_depth=10 ..................
# [CV] ......... max_features=1.0, n_estimators=5, max_depth=10 -   0.2s
# [CV] max_features=1.0, n_estimators=5, max_depth=10 ..................
# [CV] ......... max_features=1.0, n_estimators=5, max_depth=10 -   0.2s
# [CV] max_features=1.0, n_estimators=5, max_depth=10 ..................
# [CV] ......... max_features=1.0, n_estimators=5, max_depth=10 -   0.3s
# [CV] max_features=1.0, n_estimators=11, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=11, max_depth=10 -   0.2s
# [CV] max_features=1.0, n_estimators=11, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=11, max_depth=10 -   0.2s
# [CV] max_features=1.0, n_estimators=11, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=11, max_depth=10 -   0.2s
# [CV] max_features=1.0, n_estimators=11, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=11, max_depth=10 -   0.3s
# [CV] max_features=1.0, n_estimators=11, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=11, max_depth=10 -   0.2s
# [CV] max_features=1.0, n_estimators=24, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=24, max_depth=10 -   0.2s
# [CV] max_features=1.0, n_estimators=24, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=24, max_depth=10 -   0.2s
# [CV] max_features=1.0, n_estimators=24, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=24, max_depth=10 -   0.2s
# [CV] max_features=1.0, n_estimators=24, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=24, max_depth=10 -   0.2s
# [CV] max_features=1.0, n_estimators=24, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=24, max_depth=10 -   0.2s
# [CV] max_features=1.0, n_estimators=56, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=56, max_depth=10 -   0.4s
# [CV] max_features=1.0, n_estimators=56, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=56, max_depth=10 -   0.4s
# [CV] max_features=1.0, n_estimators=56, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=56, max_depth=10 -   0.4s
# [CV] max_features=1.0, n_estimators=56, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=56, max_depth=10 -   0.4s
# [CV] max_features=1.0, n_estimators=56, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=56, max_depth=10 -   0.4s
# [CV] max_features=1.0, n_estimators=128, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=128, max_depth=10 -   0.7s
# [CV] max_features=1.0, n_estimators=128, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=128, max_depth=10 -   0.8s
# [CV] max_features=1.0, n_estimators=128, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=128, max_depth=10 -   0.8s
# [CV] max_features=1.0, n_estimators=128, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=128, max_depth=10 -   0.8s
# [CV] max_features=1.0, n_estimators=128, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=128, max_depth=10 -   1.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:   13.2s finished
# Report scores
# [mean: -1615862157.86463, std: 659670094.30769, params: {'max_features': 1.0, 'n_estimators': 2, 'max_depth': 10}, mean: -1217927870.98788, std: 374520596.19878, params: {'max_features': 1.0, 'n_estimators': 5, 'max_depth': 10}, mean: -1075624722.51414, std: 370614251.96174, params: {'max_features': 1.0, 'n_estimators': 11, 'max_depth': 10}, mean: -1042479549.88535, std: 327183912.94519, params: {'max_features': 1.0, 'n_estimators': 24, 'max_depth': 10}, mean: -1004085882.22755, std: 319802167.79886, params: {'max_features': 1.0, 'n_estimators': 56, 'max_depth': 10}, mean: -958145258.25019, std: 309216166.47610, params: {'max_features': 1.0, 'n_estimators': 128, 'max_depth': 10}]
# Report best params
# ('score:', -958145258.250185)
# max_depth: 10
# max_features: 1.0
# n_estimators: 128
# Params for best estimator are  {'warm_start': False, 'oob_score': False, 'n_jobs': -1, 'verbose': 0, 'max_leaf_nodes': None, 'bootstrap': True, 'min_samples_leaf': 1, 'n_estimators': 128, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'criterion': 'mse', 'random_state': 42, 'min_impurity_split': 1e-07, 'max_features': 1.0, 'max_depth': 10}
# Now predict
# RMSE 0.153039773137
# Std:  73284.0367282  Mean:  177550.504488
# Min:  61235.662025  Max:  557493.599479
# Update param  max_features
# The start and end meet for param  max_features . No need to update.
# Update param  n_estimators
# Param  n_estimators  has exponential distribution. One step is  1.2
# Finding best param for value  128
# Convert exp back to power  128 -> 7.0
# Best index is  -1
# The param falls in the middle of range
# Update param  max_depth
# The start and end meet for param  max_depth . No need to update.
# Params updated:  {'n_estimators': {'start': 5.7999999999999998, 'end': 8.1999999999999993, 'dist': 'exp', 'type': 'int'}, 'max_features': {'start': 1.0, 'end': 1.0, 'dist': 'linear', 'type': 'float'}, 'max_depth': {'start': 10, 'end': 10, 'dist': 'linear', 'type': 'int'}}
# Go to next turn
# This iteration is for params  {'n_estimators': {'start': 5.7999999999999998, 'end': 8.1999999999999993, 'dist': 'exp', 'type': 'int'}, 'max_features': {'start': 1.0, 'end': 1.0, 'dist': 'linear', 'type': 'float'}, 'max_depth': {'start': 10, 'end': 10, 'dist': 'linear', 'type': 'int'}}
# Grinding param  n_estimators
#
# Grinding param  max_features
#
# Grinding param  max_depth
#
# Grinded params to  {'n_estimators': array([  55.71523605,   77.7084726 ,  108.38339998,  151.16706066,
#         210.83930042,  294.06677888]), 'max_features': [1.0], 'max_depth': [10]}
# Rounding param  n_estimators with list  [  55.71523605   77.7084726   108.38339998  151.16706066  210.83930042
#   294.06677888]
# Now rounded to  [ 56  78 108 151 211 294]
# Rounding param  max_depth with list  [10]
# Now rounded to  [10]
# Grinded params are rounded to  {'n_estimators': array([ 56,  78, 108, 151, 211, 294]), 'max_features': [1.0], 'max_depth': array([10])}
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] max_features=1.0, n_estimators=56, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=56, max_depth=10 -   0.4s
# [CV] max_features=1.0, n_estimators=56, max_depth=10 .................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [CV] ........ max_features=1.0, n_estimators=56, max_depth=10 -   0.4s
# [CV] max_features=1.0, n_estimators=56, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=56, max_depth=10 -   0.4s
# [CV] max_features=1.0, n_estimators=56, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=56, max_depth=10 -   0.4s
# [CV] max_features=1.0, n_estimators=56, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=56, max_depth=10 -   0.4s
# [CV] max_features=1.0, n_estimators=78, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=78, max_depth=10 -   0.5s
# [CV] max_features=1.0, n_estimators=78, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=78, max_depth=10 -   0.6s
# [CV] max_features=1.0, n_estimators=78, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=78, max_depth=10 -   0.7s
# [CV] max_features=1.0, n_estimators=78, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=78, max_depth=10 -   0.6s
# [CV] max_features=1.0, n_estimators=78, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=78, max_depth=10 -   0.5s
# [CV] max_features=1.0, n_estimators=108, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=108, max_depth=10 -   0.8s
# [CV] max_features=1.0, n_estimators=108, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=108, max_depth=10 -   0.9s
# [CV] max_features=1.0, n_estimators=108, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=108, max_depth=10 -   0.8s
# [CV] max_features=1.0, n_estimators=108, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=108, max_depth=10 -   0.8s
# [CV] max_features=1.0, n_estimators=108, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=108, max_depth=10 -   0.7s
# [CV] max_features=1.0, n_estimators=151, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=151, max_depth=10 -   0.9s
# [CV] max_features=1.0, n_estimators=151, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=151, max_depth=10 -   1.0s
# [CV] max_features=1.0, n_estimators=151, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=151, max_depth=10 -   1.0s
# [CV] max_features=1.0, n_estimators=151, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=151, max_depth=10 -   1.1s
# [CV] max_features=1.0, n_estimators=151, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=151, max_depth=10 -   1.0s
# [CV] max_features=1.0, n_estimators=211, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=211, max_depth=10 -   1.7s
# [CV] max_features=1.0, n_estimators=211, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=211, max_depth=10 -   1.3s
# [CV] max_features=1.0, n_estimators=211, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=211, max_depth=10 -   1.3s
# [CV] max_features=1.0, n_estimators=211, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=211, max_depth=10 -   1.9s
# [CV] max_features=1.0, n_estimators=211, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=211, max_depth=10 -   1.5s
# [CV] max_features=1.0, n_estimators=294, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=294, max_depth=10 -   1.7s
# [CV] max_features=1.0, n_estimators=294, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=294, max_depth=10 -   1.8s
# [CV] max_features=1.0, n_estimators=294, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=294, max_depth=10 -   2.0s
# [CV] max_features=1.0, n_estimators=294, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=294, max_depth=10 -   2.0s
# [CV] max_features=1.0, n_estimators=294, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=294, max_depth=10 -   2.3s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:   34.5s finished
# Report scores
# [mean: -1004085882.22755, std: 319802167.79886, params: {'max_features': 1.0, 'n_estimators': 56, 'max_depth': 10}, mean: -974264005.04165, std: 304086412.70710, params: {'max_features': 1.0, 'n_estimators': 78, 'max_depth': 10}, mean: -961599846.68943, std: 300574143.33689, params: {'max_features': 1.0, 'n_estimators': 108, 'max_depth': 10}, mean: -963060864.99602, std: 304900450.24861, params: {'max_features': 1.0, 'n_estimators': 151, 'max_depth': 10}, mean: -965203893.58234, std: 300386362.48463, params: {'max_features': 1.0, 'n_estimators': 211, 'max_depth': 10}, mean: -964532993.96238, std: 299668891.48960, params: {'max_features': 1.0, 'n_estimators': 294, 'max_depth': 10}]
# Report best params
# ('score:', -961599846.6894273)
# max_depth: 10
# max_features: 1.0
# n_estimators: 108
# Params for best estimator are  {'warm_start': False, 'oob_score': False, 'n_jobs': -1, 'verbose': 0, 'max_leaf_nodes': None, 'bootstrap': True, 'min_samples_leaf': 1, 'n_estimators': 108, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'criterion': 'mse', 'random_state': 42, 'min_impurity_split': 1e-07, 'max_features': 1.0, 'max_depth': 10}
# Now predict
# RMSE 0.152627575521
# Std:  73409.2585178  Mean:  177603.682954
# Min:  62300.7136747  Max:  559118.935802
# Update param  max_features
# The start and end meet for param  max_features . No need to update.
# Update param  n_estimators
# Param  n_estimators  has exponential distribution. One step is  0.48
# Finding best param for value  108
# Convert exp back to power  108 -> 6.75488750216
# Best index is  -1
# The param falls in the middle of range
# Update param  max_depth
# The start and end meet for param  max_depth . No need to update.
# Params updated:  {'n_estimators': {'start': 6.2748875021634696, 'end': 7.2348875021634687, 'dist': 'exp', 'type': 'int'}, 'max_features': {'start': 1.0, 'end': 1.0, 'dist': 'linear', 'type': 'float'}, 'max_depth': {'start': 10, 'end': 10, 'dist': 'linear', 'type': 'int'}}
# Go to next turn
# This iteration is for params  {'n_estimators': {'start': 6.2748875021634696, 'end': 7.2348875021634687, 'dist': 'exp', 'type': 'int'}, 'max_features': {'start': 1.0, 'end': 1.0, 'dist': 'linear', 'type': 'float'}, 'max_depth': {'start': 10, 'end': 10, 'dist': 'linear', 'type': 'int'}}
# Grinding param  n_estimators
#
# Grinding param  max_features
#
# Grinding param  max_depth
#
# Grinded params to  {'n_estimators': array([  77.43358339,   88.45596337,  101.04733777,  115.43104705,
#         131.86222337,  150.63231597]), 'max_features': [1.0], 'max_depth': [10]}
# Rounding param  n_estimators with list  [  77.43358339   88.45596337  101.04733777  115.43104705  131.86222337
#   150.63231597]
# Now rounded to  [ 77  88 101 115 132 151]
# Rounding param  max_depth with list  [10]
# Now rounded to  [10]
# Grinded params are rounded to  {'n_estimators': array([ 77,  88, 101, 115, 132, 151]), 'max_features': [1.0], 'max_depth': array([10])}
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] max_features=1.0, n_estimators=77, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=77, max_depth=10 -   0.6s
# [CV] max_features=1.0, n_estimators=77, max_depth=10 .................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s remaining:    0.0s
# [CV] ........ max_features=1.0, n_estimators=77, max_depth=10 -   0.7s
# [CV] max_features=1.0, n_estimators=77, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=77, max_depth=10 -   0.6s
# [CV] max_features=1.0, n_estimators=77, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=77, max_depth=10 -   0.5s
# [CV] max_features=1.0, n_estimators=77, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=77, max_depth=10 -   0.5s
# [CV] max_features=1.0, n_estimators=88, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=88, max_depth=10 -   0.6s
# [CV] max_features=1.0, n_estimators=88, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=88, max_depth=10 -   0.6s
# [CV] max_features=1.0, n_estimators=88, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=88, max_depth=10 -   0.6s
# [CV] max_features=1.0, n_estimators=88, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=88, max_depth=10 -   0.5s
# [CV] max_features=1.0, n_estimators=88, max_depth=10 .................
# [CV] ........ max_features=1.0, n_estimators=88, max_depth=10 -   0.7s
# [CV] max_features=1.0, n_estimators=101, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=101, max_depth=10 -   0.6s
# [CV] max_features=1.0, n_estimators=101, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=101, max_depth=10 -   0.8s
# [CV] max_features=1.0, n_estimators=101, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=101, max_depth=10 -   0.7s
# [CV] max_features=1.0, n_estimators=101, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=101, max_depth=10 -   0.8s
# [CV] max_features=1.0, n_estimators=101, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=101, max_depth=10 -   0.8s
# [CV] max_features=1.0, n_estimators=115, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=115, max_depth=10 -   0.9s
# [CV] max_features=1.0, n_estimators=115, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=115, max_depth=10 -   0.9s
# [CV] max_features=1.0, n_estimators=115, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=115, max_depth=10 -   0.9s
# [CV] max_features=1.0, n_estimators=115, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=115, max_depth=10 -   0.9s
# [CV] max_features=1.0, n_estimators=115, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=115, max_depth=10 -   0.9s
# [CV] max_features=1.0, n_estimators=132, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=132, max_depth=10 -   0.9s
# [CV] max_features=1.0, n_estimators=132, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=132, max_depth=10 -   0.8s
# [CV] max_features=1.0, n_estimators=132, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=132, max_depth=10 -   0.9s
# [CV] max_features=1.0, n_estimators=132, max_depth=10 ................
# [CV] ....... max_features=1.0, n_estimators=132, max_depth=10 -   0.8s
# [CV] max_features=1.0, n_estimators=132, max_depth=10 ................

# %%
from sklearn.ensemble import ExtraTreesRegressor

print "ExtraTreesRegressor"
params={
    'n_estimators':{
        'start':1,
        'end':800,
        'type':'int'
    },
    'max_features':{
        'start':0.0001,
        'end':1.0,
        'type':'float'
    },
    'max_depth':{
        'start':1,
        'end':40,
        'type':'int'
    }
        }
etr = ExtraTreesRegressor(criterion='mse', n_jobs=-1,random_state=42)
auto_param_search(etr,params,5, X_train, y_train, X_test, y_test)

# %%
from sklearn.ensemble import AdaBoostRegressor

print "Adaboost"
params={
    'n_estimators':{
        'start':200,
        'end':250,
        'type':'int'
    },
    'learning_rate':{
        'start':0.18,
        'end':0.22,
        'type':'float'
    }
}
abr = AdaBoostRegressor(loss='linear',random_state=42)
auto_param_search(abr,params,2, X_train, y_train, X_test, y_test)
# Out:
# Adaboost
# 2  iterations of search for regressor
# <class 'sklearn.ensemble.weight_boosting.AdaBoostRegressor'>
# Starting param range is  {'n_estimators': {'start': 200, 'end': 250, 'type': 'int'}, 'learning_rate': {'start': 0.18, 'end': 0.22, 'type': 'float'}}
# This iteration is for params  {'n_estimators': {'start': 200, 'end': 250, 'type': 'int'}, 'learning_rate': {'start': 0.18, 'end': 0.22, 'type': 'float'}}
# Grinding param  n_estimators
# Grinding param  learning_rate
# Grinded params to  {'n_estimators': array([ 200.,  210.,  220.,  230.,  240.,  250.]), 'learning_rate': array([ 0.18 ,  0.188,  0.196,  0.204,  0.212,  0.22 ])}
# Rounding param  n_estimators with list  [ 200.  210.  220.  230.  240.  250.]
# Now rounded to  [200 210 220 230 240 250]
# Grinded params are rounded to  {'n_estimators': array([200, 210, 220, 230, 240, 250]), 'learning_rate': array([ 0.18 ,  0.188,  0.196,  0.204,  0.212,  0.22 ])}
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] n_estimators=200, learning_rate=0.18 ............................
# [CV] ................... n_estimators=200, learning_rate=0.18 -   1.5s
# [CV] n_estimators=200, learning_rate=0.18 ............................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# [CV] ................... n_estimators=200, learning_rate=0.18 -   1.5s
# [CV] n_estimators=200, learning_rate=0.18 ............................
# [CV] ................... n_estimators=200, learning_rate=0.18 -   1.6s
# [CV] n_estimators=200, learning_rate=0.18 ............................
# [CV] ................... n_estimators=200, learning_rate=0.18 -   1.4s
# [CV] n_estimators=200, learning_rate=0.18 ............................
# [CV] ................... n_estimators=200, learning_rate=0.18 -   1.4s
# [CV] n_estimators=210, learning_rate=0.18 ............................
# [CV] ................... n_estimators=210, learning_rate=0.18 -   1.6s
# [CV] n_estimators=210, learning_rate=0.18 ............................
# [CV] ................... n_estimators=210, learning_rate=0.18 -   1.6s
# [CV] n_estimators=210, learning_rate=0.18 ............................
# [CV] ................... n_estimators=210, learning_rate=0.18 -   1.4s
# [CV] n_estimators=210, learning_rate=0.18 ............................
# [CV] ................... n_estimators=210, learning_rate=0.18 -   1.4s
# [CV] n_estimators=210, learning_rate=0.18 ............................
# [CV] ................... n_estimators=210, learning_rate=0.18 -   1.4s
# [CV] n_estimators=220, learning_rate=0.18 ............................
# [CV] ................... n_estimators=220, learning_rate=0.18 -   1.5s
# [CV] n_estimators=220, learning_rate=0.18 ............................
# [CV] ................... n_estimators=220, learning_rate=0.18 -   1.5s
# [CV] n_estimators=220, learning_rate=0.18 ............................
# [CV] ................... n_estimators=220, learning_rate=0.18 -   1.5s
# [CV] n_estimators=220, learning_rate=0.18 ............................
# [CV] ................... n_estimators=220, learning_rate=0.18 -   1.8s
# [CV] n_estimators=220, learning_rate=0.18 ............................
# [CV] ................... n_estimators=220, learning_rate=0.18 -   1.5s
# [CV] n_estimators=230, learning_rate=0.18 ............................
# [CV] ................... n_estimators=230, learning_rate=0.18 -   1.6s
# [CV] n_estimators=230, learning_rate=0.18 ............................
# [CV] ................... n_estimators=230, learning_rate=0.18 -   1.5s
# [CV] n_estimators=230, learning_rate=0.18 ............................
# [CV] ................... n_estimators=230, learning_rate=0.18 -   1.6s
# [CV] n_estimators=230, learning_rate=0.18 ............................
# [CV] ................... n_estimators=230, learning_rate=0.18 -   1.5s
# [CV] n_estimators=230, learning_rate=0.18 ............................
# [CV] ................... n_estimators=230, learning_rate=0.18 -   1.7s
# [CV] n_estimators=240, learning_rate=0.18 ............................
# [CV] ................... n_estimators=240, learning_rate=0.18 -   1.6s
# [CV] n_estimators=240, learning_rate=0.18 ............................
# [CV] ................... n_estimators=240, learning_rate=0.18 -   2.1s
# [CV] n_estimators=240, learning_rate=0.18 ............................
# [CV] ................... n_estimators=240, learning_rate=0.18 -   2.1s
# [CV] n_estimators=240, learning_rate=0.18 ............................
# [CV] ................... n_estimators=240, learning_rate=0.18 -   2.1s
# [CV] n_estimators=240, learning_rate=0.18 ............................
# [CV] ................... n_estimators=240, learning_rate=0.18 -   1.7s
# [CV] n_estimators=250, learning_rate=0.18 ............................
# [CV] ................... n_estimators=250, learning_rate=0.18 -   1.7s
# [CV] n_estimators=250, learning_rate=0.18 ............................
# [CV] ................... n_estimators=250, learning_rate=0.18 -   2.2s
# [CV] n_estimators=250, learning_rate=0.18 ............................
# [CV] ................... n_estimators=250, learning_rate=0.18 -   2.3s
# [CV] n_estimators=250, learning_rate=0.18 ............................
# [CV] ................... n_estimators=250, learning_rate=0.18 -   2.2s
# [CV] n_estimators=250, learning_rate=0.18 ............................
# [CV] ................... n_estimators=250, learning_rate=0.18 -   2.2s
# [CV] n_estimators=200, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=200, learning_rate=0.188 -   1.8s
# [CV] n_estimators=200, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=200, learning_rate=0.188 -   1.8s
# [CV] n_estimators=200, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=200, learning_rate=0.188 -   1.4s
# [CV] n_estimators=200, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=200, learning_rate=0.188 -   1.3s
# [CV] n_estimators=200, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=200, learning_rate=0.188 -   1.4s
# [CV] n_estimators=210, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=210, learning_rate=0.188 -   1.5s
# [CV] n_estimators=210, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=210, learning_rate=0.188 -   1.4s
# [CV] n_estimators=210, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=210, learning_rate=0.188 -   1.4s
# [CV] n_estimators=210, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=210, learning_rate=0.188 -   1.4s
# [CV] n_estimators=210, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=210, learning_rate=0.188 -   1.4s
# [CV] n_estimators=220, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=220, learning_rate=0.188 -   1.5s
# [CV] n_estimators=220, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=220, learning_rate=0.188 -   1.5s
# [CV] n_estimators=220, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=220, learning_rate=0.188 -   2.0s
# [CV] n_estimators=220, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=220, learning_rate=0.188 -   2.0s
# [CV] n_estimators=220, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=220, learning_rate=0.188 -   2.0s
# [CV] n_estimators=230, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=230, learning_rate=0.188 -   2.1s
# [CV] n_estimators=230, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=230, learning_rate=0.188 -   2.0s
# [CV] n_estimators=230, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=230, learning_rate=0.188 -   2.2s
# [CV] n_estimators=230, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=230, learning_rate=0.188 -   2.1s
# [CV] n_estimators=230, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=230, learning_rate=0.188 -   2.1s
# [CV] n_estimators=240, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=240, learning_rate=0.188 -   2.1s
# [CV] n_estimators=240, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=240, learning_rate=0.188 -   2.2s
# [CV] n_estimators=240, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=240, learning_rate=0.188 -   2.3s
# [CV] n_estimators=240, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=240, learning_rate=0.188 -   2.1s
# [CV] n_estimators=240, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=240, learning_rate=0.188 -   2.1s
# [CV] n_estimators=250, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=250, learning_rate=0.188 -   2.2s
# [CV] n_estimators=250, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=250, learning_rate=0.188 -   2.3s
# [CV] n_estimators=250, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=250, learning_rate=0.188 -   2.6s
# [CV] n_estimators=250, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=250, learning_rate=0.188 -   2.8s
# [CV] n_estimators=250, learning_rate=0.188 ...........................
# [CV] .................. n_estimators=250, learning_rate=0.188 -   2.2s
# [CV] n_estimators=200, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=200, learning_rate=0.196 -   2.0s
# [CV] n_estimators=200, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=200, learning_rate=0.196 -   2.2s
# [CV] n_estimators=200, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=200, learning_rate=0.196 -   2.2s
# [CV] n_estimators=200, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=200, learning_rate=0.196 -   1.9s
# [CV] n_estimators=200, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=200, learning_rate=0.196 -   1.7s
# [CV] n_estimators=210, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=210, learning_rate=0.196 -   1.8s
# [CV] n_estimators=210, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=210, learning_rate=0.196 -   2.0s
# [CV] n_estimators=210, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=210, learning_rate=0.196 -   1.9s
# [CV] n_estimators=210, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=210, learning_rate=0.196 -   2.2s
# [CV] n_estimators=210, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=210, learning_rate=0.196 -   2.5s
# [CV] n_estimators=220, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=220, learning_rate=0.196 -   2.0s
# [CV] n_estimators=220, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=220, learning_rate=0.196 -   1.9s
# [CV] n_estimators=220, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=220, learning_rate=0.196 -   2.4s
# [CV] n_estimators=220, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=220, learning_rate=0.196 -   1.9s
# [CV] n_estimators=220, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=220, learning_rate=0.196 -   2.0s
# [CV] n_estimators=230, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=230, learning_rate=0.196 -   2.1s
# [CV] n_estimators=230, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=230, learning_rate=0.196 -   2.1s
# [CV] n_estimators=230, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=230, learning_rate=0.196 -   2.1s
# [CV] n_estimators=230, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=230, learning_rate=0.196 -   2.2s
# [CV] n_estimators=230, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=230, learning_rate=0.196 -   2.0s
# [CV] n_estimators=240, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=240, learning_rate=0.196 -   2.1s
# [CV] n_estimators=240, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=240, learning_rate=0.196 -   2.1s
# [CV] n_estimators=240, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=240, learning_rate=0.196 -   2.1s
# [CV] n_estimators=240, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=240, learning_rate=0.196 -   2.1s
# [CV] n_estimators=240, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=240, learning_rate=0.196 -   2.1s
# [CV] n_estimators=250, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=250, learning_rate=0.196 -   2.2s
# [CV] n_estimators=250, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=250, learning_rate=0.196 -   2.3s
# [CV] n_estimators=250, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=250, learning_rate=0.196 -   2.3s
# [CV] n_estimators=250, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=250, learning_rate=0.196 -   2.3s
# [CV] n_estimators=250, learning_rate=0.196 ...........................
# [CV] .................. n_estimators=250, learning_rate=0.196 -   2.2s
# [CV] n_estimators=200, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=200, learning_rate=0.204 -   1.3s
# [CV] n_estimators=200, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=200, learning_rate=0.204 -   1.4s
# [CV] n_estimators=200, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=200, learning_rate=0.204 -   1.9s
# [CV] n_estimators=200, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=200, learning_rate=0.204 -   1.8s
# [CV] n_estimators=200, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=200, learning_rate=0.204 -   1.8s
# [CV] n_estimators=210, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=210, learning_rate=0.204 -   2.3s
# [CV] n_estimators=210, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=210, learning_rate=0.204 -   2.0s
# [CV] n_estimators=210, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=210, learning_rate=0.204 -   1.8s
# [CV] n_estimators=210, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=210, learning_rate=0.204 -   2.0s
# [CV] n_estimators=210, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=210, learning_rate=0.204 -   1.8s
# [CV] n_estimators=220, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=220, learning_rate=0.204 -   2.0s
# [CV] n_estimators=220, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=220, learning_rate=0.204 -   2.0s
# [CV] n_estimators=220, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=220, learning_rate=0.204 -   1.8s
# [CV] n_estimators=220, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=220, learning_rate=0.204 -   1.5s
# [CV] n_estimators=220, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=220, learning_rate=0.204 -   1.5s
# [CV] n_estimators=230, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=230, learning_rate=0.204 -   1.6s
# [CV] n_estimators=230, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=230, learning_rate=0.204 -   1.6s
# [CV] n_estimators=230, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=230, learning_rate=0.204 -   1.5s
# [CV] n_estimators=230, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=230, learning_rate=0.204 -   1.6s
# [CV] n_estimators=230, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=230, learning_rate=0.204 -   1.6s
# [CV] n_estimators=240, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=240, learning_rate=0.204 -   2.2s
# [CV] n_estimators=240, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=240, learning_rate=0.204 -   2.2s
# [CV] n_estimators=240, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=240, learning_rate=0.204 -   2.2s
# [CV] n_estimators=240, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=240, learning_rate=0.204 -   2.2s
# [CV] n_estimators=240, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=240, learning_rate=0.204 -   2.3s
# [CV] n_estimators=250, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=250, learning_rate=0.204 -   2.3s
# [CV] n_estimators=250, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=250, learning_rate=0.204 -   2.3s
# [CV] n_estimators=250, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=250, learning_rate=0.204 -   2.3s
# [CV] n_estimators=250, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=250, learning_rate=0.204 -   2.3s
# [CV] n_estimators=250, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=250, learning_rate=0.204 -   2.2s
# [CV] n_estimators=200, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=200, learning_rate=0.212 -   1.8s
# [CV] n_estimators=200, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=200, learning_rate=0.212 -   1.8s
# [CV] n_estimators=200, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=200, learning_rate=0.212 -   1.8s
# [CV] n_estimators=200, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=200, learning_rate=0.212 -   1.8s
# [CV] n_estimators=200, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=200, learning_rate=0.212 -   1.8s
# [CV] n_estimators=210, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=210, learning_rate=0.212 -   1.9s
# [CV] n_estimators=210, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=210, learning_rate=0.212 -   1.9s
# [CV] n_estimators=210, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=210, learning_rate=0.212 -   1.9s
# [CV] n_estimators=210, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=210, learning_rate=0.212 -   1.9s
# [CV] n_estimators=210, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=210, learning_rate=0.212 -   1.9s
# [CV] n_estimators=220, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=220, learning_rate=0.212 -   2.0s
# [CV] n_estimators=220, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=220, learning_rate=0.212 -   2.0s
# [CV] n_estimators=220, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=220, learning_rate=0.212 -   2.0s
# [CV] n_estimators=220, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=220, learning_rate=0.212 -   2.0s
# [CV] n_estimators=220, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=220, learning_rate=0.212 -   2.0s
# [CV] n_estimators=230, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=230, learning_rate=0.212 -   2.0s
# [CV] n_estimators=230, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=230, learning_rate=0.212 -   2.0s
# [CV] n_estimators=230, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=230, learning_rate=0.212 -   2.0s
# [CV] n_estimators=230, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=230, learning_rate=0.212 -   2.0s
# [CV] n_estimators=230, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=230, learning_rate=0.212 -   2.0s
# [CV] n_estimators=240, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=240, learning_rate=0.212 -   2.1s
# [CV] n_estimators=240, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=240, learning_rate=0.212 -   2.2s
# [CV] n_estimators=240, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=240, learning_rate=0.212 -   2.2s
# [CV] n_estimators=240, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=240, learning_rate=0.212 -   2.4s
# [CV] n_estimators=240, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=240, learning_rate=0.212 -   2.3s
# [CV] n_estimators=250, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=250, learning_rate=0.212 -   2.3s
# [CV] n_estimators=250, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=250, learning_rate=0.212 -   2.2s
# [CV] n_estimators=250, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=250, learning_rate=0.212 -   2.3s
# [CV] n_estimators=250, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=250, learning_rate=0.212 -   2.3s
# [CV] n_estimators=250, learning_rate=0.212 ...........................
# [CV] .................. n_estimators=250, learning_rate=0.212 -   2.2s
# [CV] n_estimators=200, learning_rate=0.22 ............................
# [CV] ................... n_estimators=200, learning_rate=0.22 -   2.0s
# [CV] n_estimators=200, learning_rate=0.22 ............................
# [CV] ................... n_estimators=200, learning_rate=0.22 -   1.8s
# [CV] n_estimators=200, learning_rate=0.22 ............................
# [CV] ................... n_estimators=200, learning_rate=0.22 -   1.8s
# [CV] n_estimators=200, learning_rate=0.22 ............................
# [CV] ................... n_estimators=200, learning_rate=0.22 -   1.9s
# [CV] n_estimators=200, learning_rate=0.22 ............................
# [CV] ................... n_estimators=200, learning_rate=0.22 -   1.8s
# [CV] n_estimators=210, learning_rate=0.22 ............................
# [CV] ................... n_estimators=210, learning_rate=0.22 -   1.9s
# [CV] n_estimators=210, learning_rate=0.22 ............................
# [CV] ................... n_estimators=210, learning_rate=0.22 -   1.9s
# [CV] n_estimators=210, learning_rate=0.22 ............................
# [CV] ................... n_estimators=210, learning_rate=0.22 -   2.0s
# [CV] n_estimators=210, learning_rate=0.22 ............................
# [CV] ................... n_estimators=210, learning_rate=0.22 -   1.9s
# [CV] n_estimators=210, learning_rate=0.22 ............................
# [CV] ................... n_estimators=210, learning_rate=0.22 -   1.9s
# [CV] n_estimators=220, learning_rate=0.22 ............................
# [CV] ................... n_estimators=220, learning_rate=0.22 -   2.0s
# [CV] n_estimators=220, learning_rate=0.22 ............................
# [CV] ................... n_estimators=220, learning_rate=0.22 -   2.0s
# [CV] n_estimators=220, learning_rate=0.22 ............................
# [CV] ................... n_estimators=220, learning_rate=0.22 -   2.0s
# [CV] n_estimators=220, learning_rate=0.22 ............................
# [CV] ................... n_estimators=220, learning_rate=0.22 -   2.0s
# [CV] n_estimators=220, learning_rate=0.22 ............................
# [CV] ................... n_estimators=220, learning_rate=0.22 -   2.0s
# [CV] n_estimators=230, learning_rate=0.22 ............................
# [CV] ................... n_estimators=230, learning_rate=0.22 -   2.1s
# [CV] n_estimators=230, learning_rate=0.22 ............................
# [CV] ................... n_estimators=230, learning_rate=0.22 -   2.1s
# [CV] n_estimators=230, learning_rate=0.22 ............................
# [CV] ................... n_estimators=230, learning_rate=0.22 -   2.1s
# [CV] n_estimators=230, learning_rate=0.22 ............................
# [CV] ................... n_estimators=230, learning_rate=0.22 -   2.1s
# [CV] n_estimators=230, learning_rate=0.22 ............................
# [CV] ................... n_estimators=230, learning_rate=0.22 -   2.0s
# [CV] n_estimators=240, learning_rate=0.22 ............................
# [CV] ................... n_estimators=240, learning_rate=0.22 -   2.2s
# [CV] n_estimators=240, learning_rate=0.22 ............................
# [CV] ................... n_estimators=240, learning_rate=0.22 -   2.2s
# [CV] n_estimators=240, learning_rate=0.22 ............................
# [CV] ................... n_estimators=240, learning_rate=0.22 -   2.3s
# [CV] n_estimators=240, learning_rate=0.22 ............................
# [CV] ................... n_estimators=240, learning_rate=0.22 -   2.1s
# [CV] n_estimators=240, learning_rate=0.22 ............................
# [CV] ................... n_estimators=240, learning_rate=0.22 -   2.2s
# [CV] n_estimators=250, learning_rate=0.22 ............................
# [CV] ................... n_estimators=250, learning_rate=0.22 -   2.2s
# [CV] n_estimators=250, learning_rate=0.22 ............................
# [CV] ................... n_estimators=250, learning_rate=0.22 -   2.4s
# [CV] n_estimators=250, learning_rate=0.22 ............................
# [CV] ................... n_estimators=250, learning_rate=0.22 -   2.3s
# [CV] n_estimators=250, learning_rate=0.22 ............................
# [CV] ................... n_estimators=250, learning_rate=0.22 -   2.4s
# [CV] n_estimators=250, learning_rate=0.22 ............................
# [CV] ................... n_estimators=250, learning_rate=0.22 -   2.2s
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed:  6.1min finished
# Report scores
# [mean: -1313630812.86175, std: 326255620.87724, params: {'n_estimators': 200, 'learning_rate': 0.17999999999999999}, mean: -1310472144.35669, std: 326724679.90184, params: {'n_estimators': 210, 'learning_rate': 0.17999999999999999}, mean: -1306759381.06412, std: 331280166.10577, params: {'n_estimators': 220, 'learning_rate': 0.17999999999999999}, mean: -1315969695.20024, std: 323537890.41756, params: {'n_estimators': 230, 'learning_rate': 0.17999999999999999}, mean: -1315623855.40299, std: 313887664.94822, params: {'n_estimators': 240, 'learning_rate': 0.17999999999999999}, mean: -1306272987.81688, std: 314968429.49005, params: {'n_estimators': 250, 'learning_rate': 0.17999999999999999}, mean: -1291850532.66120, std: 328368856.69797, params: {'n_estimators': 200, 'learning_rate': 0.188}, mean: -1301686200.54824, std: 316769140.12851, params: {'n_estimators': 210, 'learning_rate': 0.188}, mean: -1292382237.78233, std: 323230065.58792, params: {'n_estimators': 220, 'learning_rate': 0.188}, mean: -1309749113.66228, std: 317659733.78807, params: {'n_estimators': 230, 'learning_rate': 0.188}, mean: -1293450617.19372, std: 318020385.69139, params: {'n_estimators': 240, 'learning_rate': 0.188}, mean: -1295946468.50638, std: 317706608.50262, params: {'n_estimators': 250, 'learning_rate': 0.188}, mean: -1320273833.34217, std: 322178852.02300, params: {'n_estimators': 200, 'learning_rate': 0.19600000000000001}, mean: -1319614820.96066, std: 316434265.11234, params: {'n_estimators': 210, 'learning_rate': 0.19600000000000001}, mean: -1317578160.81652, std: 311080747.65435, params: {'n_estimators': 220, 'learning_rate': 0.19600000000000001}, mean: -1318670277.62184, std: 303261001.04739, params: {'n_estimators': 230, 'learning_rate': 0.19600000000000001}, mean: -1315828808.80701, std: 300030438.85691, params: {'n_estimators': 240, 'learning_rate': 0.19600000000000001}, mean: -1318489219.23830, std: 296484455.03526, params: {'n_estimators': 250, 'learning_rate': 0.19600000000000001}, mean: -1324576124.85420, std: 270616986.19665, params: {'n_estimators': 200, 'learning_rate': 0.20400000000000001}, mean: -1321845011.04003, std: 263738094.30852, params: {'n_estimators': 210, 'learning_rate': 0.20400000000000001}, mean: -1324017979.55644, std: 263974321.27910, params: {'n_estimators': 220, 'learning_rate': 0.20400000000000001}, mean: -1325586567.35068, std: 265063242.83792, params: {'n_estimators': 230, 'learning_rate': 0.20400000000000001}, mean: -1329293922.74406, std: 264792371.01303, params: {'n_estimators': 240, 'learning_rate': 0.20400000000000001}, mean: -1326796309.04431, std: 263237842.58669, params: {'n_estimators': 250, 'learning_rate': 0.20400000000000001}, mean: -1276973609.93859, std: 315052734.14955, params: {'n_estimators': 200, 'learning_rate': 0.21199999999999999}, mean: -1279724029.09343, std: 314664501.54328, params: {'n_estimators': 210, 'learning_rate': 0.21199999999999999}, mean: -1284431690.17019, std: 314799295.09484, params: {'n_estimators': 220, 'learning_rate': 0.21199999999999999}, mean: -1280135738.79553, std: 317979990.47631, params: {'n_estimators': 230, 'learning_rate': 0.21199999999999999}, mean: -1281937589.02212, std: 310081850.75191, params: {'n_estimators': 240, 'learning_rate': 0.21199999999999999}, mean: -1287637753.47803, std: 307567305.02309, params: {'n_estimators': 250, 'learning_rate': 0.21199999999999999}, mean: -1313601213.59299, std: 297008619.23027, params: {'n_estimators': 200, 'learning_rate': 0.22}, mean: -1314680328.09300, std: 295572000.66306, params: {'n_estimators': 210, 'learning_rate': 0.22}, mean: -1311710460.91269, std: 291891360.67007, params: {'n_estimators': 220, 'learning_rate': 0.22}, mean: -1311078004.35624, std: 282295858.32310, params: {'n_estimators': 230, 'learning_rate': 0.22}, mean: -1311680807.18114, std: 290771671.90962, params: {'n_estimators': 240, 'learning_rate': 0.22}, mean: -1315466170.93913, std: 297444606.06705, params: {'n_estimators': 250, 'learning_rate': 0.22 ...
# Report best params
# ('score:', -1276973609.9385877)
# learning_rate: 0.21199999999999999
# n_estimators: 200
# Params for best estimator are  {'n_estimators': 200, 'loss': 'linear', 'base_estimator': None, 'random_state': 42, 'learning_rate': 0.21199999999999999}
# Now predict
# RMSE 0.21758493516
# Std:  69263.6989218  Mean:  186755.623652
# Min:  117874.55303  Max:  576441.860465
# Update param  n_estimators
# Best index is  0
# Arrived at start of search range  200
# Update param  learning_rate
# Best index is  4
# Params updated:  {'n_estimators': {'start': 200, 'end': 250, 'type': 'int'}, 'learning_rate': {'start': 0.20400000000000001, 'end': 0.22, 'type': 'float'}}
# Go to next turn
# This iteration is for params  {'n_estimators': {'start': 200, 'end': 250, 'type': 'int'}, 'learning_rate': {'start': 0.20400000000000001, 'end': 0.22, 'type': 'float'}}
# Grinding param  n_estimators
# Grinding param  learning_rate
# Grinded params to  {'n_estimators': array([ 200.,  210.,  220.,  230.,  240.,  250.]), 'learning_rate': array([ 0.204 ,  0.2072,  0.2104,  0.2136,  0.2168,  0.22  ])}
# Rounding param  n_estimators with list  [ 200.  210.  220.  230.  240.  250.]
# Now rounded to  [200 210 220 230 240 250]
# Grinded params are rounded to  {'n_estimators': array([200, 210, 220, 230, 240, 250]), 'learning_rate': array([ 0.204 ,  0.2072,  0.2104,  0.2136,  0.2168,  0.22  ])}
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] n_estimators=200, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=200, learning_rate=0.204 -   1.8s
# [CV] n_estimators=200, learning_rate=0.204 ...........................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s remaining:    0.0s
# [CV] .................. n_estimators=200, learning_rate=0.204 -   1.9s
# [CV] n_estimators=200, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=200, learning_rate=0.204 -   1.8s
# [CV] n_estimators=200, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=200, learning_rate=0.204 -   1.8s
# [CV] n_estimators=200, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=200, learning_rate=0.204 -   1.8s
# [CV] n_estimators=210, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=210, learning_rate=0.204 -   2.0s
# [CV] n_estimators=210, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=210, learning_rate=0.204 -   2.0s
# [CV] n_estimators=210, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=210, learning_rate=0.204 -   1.9s
# [CV] n_estimators=210, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=210, learning_rate=0.204 -   2.0s
# [CV] n_estimators=210, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=210, learning_rate=0.204 -   1.9s
# [CV] n_estimators=220, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=220, learning_rate=0.204 -   2.0s
# [CV] n_estimators=220, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=220, learning_rate=0.204 -   2.0s
# [CV] n_estimators=220, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=220, learning_rate=0.204 -   2.0s
# [CV] n_estimators=220, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=220, learning_rate=0.204 -   2.1s
# [CV] n_estimators=220, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=220, learning_rate=0.204 -   2.0s
# [CV] n_estimators=230, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=230, learning_rate=0.204 -   2.1s
# [CV] n_estimators=230, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=230, learning_rate=0.204 -   2.1s
# [CV] n_estimators=230, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=230, learning_rate=0.204 -   2.2s
# [CV] n_estimators=230, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=230, learning_rate=0.204 -   2.1s
# [CV] n_estimators=230, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=230, learning_rate=0.204 -   2.1s
# [CV] n_estimators=240, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=240, learning_rate=0.204 -   2.3s
# [CV] n_estimators=240, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=240, learning_rate=0.204 -   2.3s
# [CV] n_estimators=240, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=240, learning_rate=0.204 -   2.2s
# [CV] n_estimators=240, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=240, learning_rate=0.204 -   2.2s
# [CV] n_estimators=240, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=240, learning_rate=0.204 -   2.2s
# [CV] n_estimators=250, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=250, learning_rate=0.204 -   2.3s
# [CV] n_estimators=250, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=250, learning_rate=0.204 -   2.2s
# [CV] n_estimators=250, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=250, learning_rate=0.204 -   2.3s
# [CV] n_estimators=250, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=250, learning_rate=0.204 -   2.3s
# [CV] n_estimators=250, learning_rate=0.204 ...........................
# [CV] .................. n_estimators=250, learning_rate=0.204 -   2.2s
# [CV] n_estimators=200, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=200, learning_rate=0.2072 -   1.8s
# [CV] n_estimators=200, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=200, learning_rate=0.2072 -   1.8s
# [CV] n_estimators=200, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=200, learning_rate=0.2072 -   1.9s
# [CV] n_estimators=200, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=200, learning_rate=0.2072 -   1.8s
# [CV] n_estimators=200, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=200, learning_rate=0.2072 -   1.8s
# [CV] n_estimators=210, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=210, learning_rate=0.2072 -   1.9s
# [CV] n_estimators=210, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=210, learning_rate=0.2072 -   1.9s
# [CV] n_estimators=210, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=210, learning_rate=0.2072 -   1.9s
# [CV] n_estimators=210, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=210, learning_rate=0.2072 -   1.8s
# [CV] n_estimators=210, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=210, learning_rate=0.2072 -   1.8s
# [CV] n_estimators=220, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=220, learning_rate=0.2072 -   1.9s
# [CV] n_estimators=220, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=220, learning_rate=0.2072 -   2.2s
# [CV] n_estimators=220, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=220, learning_rate=0.2072 -   2.1s
# [CV] n_estimators=220, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=220, learning_rate=0.2072 -   2.0s
# [CV] n_estimators=220, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=220, learning_rate=0.2072 -   2.1s
# [CV] n_estimators=230, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=230, learning_rate=0.2072 -   2.1s
# [CV] n_estimators=230, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=230, learning_rate=0.2072 -   2.1s
# [CV] n_estimators=230, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=230, learning_rate=0.2072 -   2.3s
# [CV] n_estimators=230, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=230, learning_rate=0.2072 -   2.1s
# [CV] n_estimators=230, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=230, learning_rate=0.2072 -   2.0s
# [CV] n_estimators=240, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=240, learning_rate=0.2072 -   2.3s
# [CV] n_estimators=240, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=240, learning_rate=0.2072 -   2.3s
# [CV] n_estimators=240, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=240, learning_rate=0.2072 -   2.3s
# [CV] n_estimators=240, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=240, learning_rate=0.2072 -   2.3s
# [CV] n_estimators=240, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=240, learning_rate=0.2072 -   2.3s
# [CV] n_estimators=250, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=250, learning_rate=0.2072 -   2.3s
# [CV] n_estimators=250, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=250, learning_rate=0.2072 -   2.4s
# [CV] n_estimators=250, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=250, learning_rate=0.2072 -   2.3s
# [CV] n_estimators=250, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=250, learning_rate=0.2072 -   2.2s
# [CV] n_estimators=250, learning_rate=0.2072 ..........................
# [CV] ................. n_estimators=250, learning_rate=0.2072 -   2.3s
# [CV] n_estimators=200, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=200, learning_rate=0.2104 -   1.8s
# [CV] n_estimators=200, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=200, learning_rate=0.2104 -   1.9s
# [CV] n_estimators=200, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=200, learning_rate=0.2104 -   1.9s
# [CV] n_estimators=200, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=200, learning_rate=0.2104 -   2.1s
# [CV] n_estimators=200, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=200, learning_rate=0.2104 -   1.8s
# [CV] n_estimators=210, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=210, learning_rate=0.2104 -   1.9s
# [CV] n_estimators=210, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=210, learning_rate=0.2104 -   1.9s
# [CV] n_estimators=210, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=210, learning_rate=0.2104 -   2.0s
# [CV] n_estimators=210, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=210, learning_rate=0.2104 -   1.8s
# [CV] n_estimators=210, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=210, learning_rate=0.2104 -   1.9s
# [CV] n_estimators=220, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=220, learning_rate=0.2104 -   2.0s
# [CV] n_estimators=220, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=220, learning_rate=0.2104 -   2.0s
# [CV] n_estimators=220, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=220, learning_rate=0.2104 -   1.9s
# [CV] n_estimators=220, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=220, learning_rate=0.2104 -   2.0s
# [CV] n_estimators=220, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=220, learning_rate=0.2104 -   2.0s
# [CV] n_estimators=230, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=230, learning_rate=0.2104 -   2.1s
# [CV] n_estimators=230, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=230, learning_rate=0.2104 -   2.2s
# [CV] n_estimators=230, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=230, learning_rate=0.2104 -   2.2s
# [CV] n_estimators=230, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=230, learning_rate=0.2104 -   2.2s
# [CV] n_estimators=230, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=230, learning_rate=0.2104 -   2.1s
# [CV] n_estimators=240, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=240, learning_rate=0.2104 -   2.3s
# [CV] n_estimators=240, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=240, learning_rate=0.2104 -   2.3s
# [CV] n_estimators=240, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=240, learning_rate=0.2104 -   2.2s
# [CV] n_estimators=240, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=240, learning_rate=0.2104 -   2.4s
# [CV] n_estimators=240, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=240, learning_rate=0.2104 -   2.2s
# [CV] n_estimators=250, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=250, learning_rate=0.2104 -   2.4s
# [CV] n_estimators=250, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=250, learning_rate=0.2104 -   2.4s
# [CV] n_estimators=250, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=250, learning_rate=0.2104 -   2.7s
# [CV] n_estimators=250, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=250, learning_rate=0.2104 -   2.2s
# [CV] n_estimators=250, learning_rate=0.2104 ..........................
# [CV] ................. n_estimators=250, learning_rate=0.2104 -   2.3s
# [CV] n_estimators=200, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=200, learning_rate=0.2136 -   1.8s
# [CV] n_estimators=200, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=200, learning_rate=0.2136 -   1.9s
# [CV] n_estimators=200, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=200, learning_rate=0.2136 -   2.3s
# [CV] n_estimators=200, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=200, learning_rate=0.2136 -   1.9s
# [CV] n_estimators=200, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=200, learning_rate=0.2136 -   1.9s
# [CV] n_estimators=210, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=210, learning_rate=0.2136 -   2.0s
# [CV] n_estimators=210, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=210, learning_rate=0.2136 -   2.2s
# [CV] n_estimators=210, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=210, learning_rate=0.2136 -   2.1s
# [CV] n_estimators=210, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=210, learning_rate=0.2136 -   2.1s
# [CV] n_estimators=210, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=210, learning_rate=0.2136 -   1.9s
# [CV] n_estimators=220, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=220, learning_rate=0.2136 -   2.0s
# [CV] n_estimators=220, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=220, learning_rate=0.2136 -   2.2s
# [CV] n_estimators=220, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=220, learning_rate=0.2136 -   2.0s
# [CV] n_estimators=220, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=220, learning_rate=0.2136 -   2.1s
# [CV] n_estimators=220, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=220, learning_rate=0.2136 -   2.0s
# [CV] n_estimators=230, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=230, learning_rate=0.2136 -   2.2s
# [CV] n_estimators=230, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=230, learning_rate=0.2136 -   2.3s
# [CV] n_estimators=230, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=230, learning_rate=0.2136 -   2.2s
# [CV] n_estimators=230, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=230, learning_rate=0.2136 -   2.0s
# [CV] n_estimators=230, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=230, learning_rate=0.2136 -   2.2s
# [CV] n_estimators=240, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=240, learning_rate=0.2136 -   2.1s
# [CV] n_estimators=240, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=240, learning_rate=0.2136 -   2.2s
# [CV] n_estimators=240, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=240, learning_rate=0.2136 -   2.2s
# [CV] n_estimators=240, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=240, learning_rate=0.2136 -   2.2s
# [CV] n_estimators=240, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=240, learning_rate=0.2136 -   2.1s
# [CV] n_estimators=250, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=250, learning_rate=0.2136 -   2.2s
# [CV] n_estimators=250, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=250, learning_rate=0.2136 -   2.2s
# [CV] n_estimators=250, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=250, learning_rate=0.2136 -   2.2s
# [CV] n_estimators=250, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=250, learning_rate=0.2136 -   2.2s
# [CV] n_estimators=250, learning_rate=0.2136 ..........................
# [CV] ................. n_estimators=250, learning_rate=0.2136 -   2.1s
# [CV] n_estimators=200, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=200, learning_rate=0.2168 -   1.8s
# [CV] n_estimators=200, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=200, learning_rate=0.2168 -   1.8s
# [CV] n_estimators=200, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=200, learning_rate=0.2168 -   1.9s
# [CV] n_estimators=200, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=200, learning_rate=0.2168 -   1.8s
# [CV] n_estimators=200, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=200, learning_rate=0.2168 -   1.8s
# [CV] n_estimators=210, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=210, learning_rate=0.2168 -   1.9s
# [CV] n_estimators=210, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=210, learning_rate=0.2168 -   1.8s
# [CV] n_estimators=210, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=210, learning_rate=0.2168 -   1.9s
# [CV] n_estimators=210, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=210, learning_rate=0.2168 -   1.8s
# [CV] n_estimators=210, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=210, learning_rate=0.2168 -   1.9s
# [CV] n_estimators=220, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=220, learning_rate=0.2168 -   1.9s
# [CV] n_estimators=220, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=220, learning_rate=0.2168 -   2.0s
# [CV] n_estimators=220, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=220, learning_rate=0.2168 -   1.9s
# [CV] n_estimators=220, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=220, learning_rate=0.2168 -   2.0s
# [CV] n_estimators=220, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=220, learning_rate=0.2168 -   1.9s
# [CV] n_estimators=230, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=230, learning_rate=0.2168 -   2.0s
# [CV] n_estimators=230, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=230, learning_rate=0.2168 -   2.0s
# [CV] n_estimators=230, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=230, learning_rate=0.2168 -   2.1s
# [CV] n_estimators=230, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=230, learning_rate=0.2168 -   2.0s
# [CV] n_estimators=230, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=230, learning_rate=0.2168 -   2.0s
# [CV] n_estimators=240, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=240, learning_rate=0.2168 -   2.1s
# [CV] n_estimators=240, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=240, learning_rate=0.2168 -   2.1s
# [CV] n_estimators=240, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=240, learning_rate=0.2168 -   2.2s
# [CV] n_estimators=240, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=240, learning_rate=0.2168 -   2.0s
# [CV] n_estimators=240, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=240, learning_rate=0.2168 -   1.5s
# [CV] n_estimators=250, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=250, learning_rate=0.2168 -   1.7s
# [CV] n_estimators=250, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=250, learning_rate=0.2168 -   2.0s
# [CV] n_estimators=250, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=250, learning_rate=0.2168 -   2.3s
# [CV] n_estimators=250, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=250, learning_rate=0.2168 -   2.2s
# [CV] n_estimators=250, learning_rate=0.2168 ..........................
# [CV] ................. n_estimators=250, learning_rate=0.2168 -   2.3s
# [CV] n_estimators=200, learning_rate=0.22 ............................
# [CV] ................... n_estimators=200, learning_rate=0.22 -   1.8s
# [CV] n_estimators=200, learning_rate=0.22 ............................
# [CV] ................... n_estimators=200, learning_rate=0.22 -   1.8s
# [CV] n_estimators=200, learning_rate=0.22 ............................
# [CV] ................... n_estimators=200, learning_rate=0.22 -   1.8s
# [CV] n_estimators=200, learning_rate=0.22 ............................
# [CV] ................... n_estimators=200, learning_rate=0.22 -   1.9s
# [CV] n_estimators=200, learning_rate=0.22 ............................
# [CV] ................... n_estimators=200, learning_rate=0.22 -   1.9s
# [CV] n_estimators=210, learning_rate=0.22 ............................
# [CV] ................... n_estimators=210, learning_rate=0.22 -   2.0s
# [CV] n_estimators=210, learning_rate=0.22 ............................
# [CV] ................... n_estimators=210, learning_rate=0.22 -   2.0s
# [CV] n_estimators=210, learning_rate=0.22 ............................
# [CV] ................... n_estimators=210, learning_rate=0.22 -   2.2s
# [CV] n_estimators=210, learning_rate=0.22 ............................
# [CV] ................... n_estimators=210, learning_rate=0.22 -   1.9s
# [CV] n_estimators=210, learning_rate=0.22 ............................
# [CV] ................... n_estimators=210, learning_rate=0.22 -   2.0s
# [CV] n_estimators=220, learning_rate=0.22 ............................
# [CV] ................... n_estimators=220, learning_rate=0.22 -   2.2s
# [CV] n_estimators=220, learning_rate=0.22 ............................
# [CV] ................... n_estimators=220, learning_rate=0.22 -   2.1s
# [CV] n_estimators=220, learning_rate=0.22 ............................
# [CV] ................... n_estimators=220, learning_rate=0.22 -   2.1s
# [CV] n_estimators=220, learning_rate=0.22 ............................
# [CV] ................... n_estimators=220, learning_rate=0.22 -   2.0s
# [CV] n_estimators=220, learning_rate=0.22 ............................
# [CV] ................... n_estimators=220, learning_rate=0.22 -   2.0s
# [CV] n_estimators=230, learning_rate=0.22 ............................
# [CV] ................... n_estimators=230, learning_rate=0.22 -   2.2s
# [CV] n_estimators=230, learning_rate=0.22 ............................
# [CV] ................... n_estimators=230, learning_rate=0.22 -   2.1s
# [CV] n_estimators=230, learning_rate=0.22 ............................
# [CV] ................... n_estimators=230, learning_rate=0.22 -   2.2s
# [CV] n_estimators=230, learning_rate=0.22 ............................
# [CV] ................... n_estimators=230, learning_rate=0.22 -   2.1s
# [CV] n_estimators=230, learning_rate=0.22 ............................
# [CV] ................... n_estimators=230, learning_rate=0.22 -   2.2s
# [CV] n_estimators=240, learning_rate=0.22 ............................
# [CV] ................... n_estimators=240, learning_rate=0.22 -   2.1s
# [CV] n_estimators=240, learning_rate=0.22 ............................
# [CV] ................... n_estimators=240, learning_rate=0.22 -   2.3s
# [CV] n_estimators=240, learning_rate=0.22 ............................
# [CV] ................... n_estimators=240, learning_rate=0.22 -   2.2s
# [CV] n_estimators=240, learning_rate=0.22 ............................
# [CV] ................... n_estimators=240, learning_rate=0.22 -   2.3s
# [CV] n_estimators=240, learning_rate=0.22 ............................
# [CV] ................... n_estimators=240, learning_rate=0.22 -   2.2s
# [CV] n_estimators=250, learning_rate=0.22 ............................
# [CV] ................... n_estimators=250, learning_rate=0.22 -   2.4s
# [CV] n_estimators=250, learning_rate=0.22 ............................
# [CV] ................... n_estimators=250, learning_rate=0.22 -   2.2s
# [CV] n_estimators=250, learning_rate=0.22 ............................
# [CV] ................... n_estimators=250, learning_rate=0.22 -   2.4s
# [CV] n_estimators=250, learning_rate=0.22 ............................
# [CV] ................... n_estimators=250, learning_rate=0.22 -   2.3s
# [CV] n_estimators=250, learning_rate=0.22 ............................
# [CV] ................... n_estimators=250, learning_rate=0.22 -   2.4s
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed:  6.5min finished
# Report scores
# [mean: -1324576124.85420, std: 270616986.19665, params: {'n_estimators': 200, 'learning_rate': 0.20400000000000001}, mean: -1321845011.04003, std: 263738094.30852, params: {'n_estimators': 210, 'learning_rate': 0.20400000000000001}, mean: -1324017979.55644, std: 263974321.27910, params: {'n_estimators': 220, 'learning_rate': 0.20400000000000001}, mean: -1325586567.35068, std: 265063242.83792, params: {'n_estimators': 230, 'learning_rate': 0.20400000000000001}, mean: -1329293922.74406, std: 264792371.01303, params: {'n_estimators': 240, 'learning_rate': 0.20400000000000001}, mean: -1326796309.04431, std: 263237842.58669, params: {'n_estimators': 250, 'learning_rate': 0.20400000000000001}, mean: -1299502334.43069, std: 309494347.56756, params: {'n_estimators': 200, 'learning_rate': 0.20720000000000002}, mean: -1307827214.91324, std: 305192863.41611, params: {'n_estimators': 210, 'learning_rate': 0.20720000000000002}, mean: -1304893128.24052, std: 306311354.17954, params: {'n_estimators': 220, 'learning_rate': 0.20720000000000002}, mean: -1302435087.05772, std: 306315593.35657, params: {'n_estimators': 230, 'learning_rate': 0.20720000000000002}, mean: -1305376671.46089, std: 296313646.36797, params: {'n_estimators': 240, 'learning_rate': 0.20720000000000002}, mean: -1318588304.02378, std: 291965806.80193, params: {'n_estimators': 250, 'learning_rate': 0.20720000000000002}, mean: -1309473543.56387, std: 284453466.28720, params: {'n_estimators': 200, 'learning_rate': 0.2104}, mean: -1302942265.26867, std: 299614463.82388, params: {'n_estimators': 210, 'learning_rate': 0.2104}, mean: -1326407089.42209, std: 282076753.76641, params: {'n_estimators': 220, 'learning_rate': 0.2104}, mean: -1325115454.65399, std: 275927649.69309, params: {'n_estimators': 230, 'learning_rate': 0.2104}, mean: -1321822904.20710, std: 268392334.21386, params: {'n_estimators': 240, 'learning_rate': 0.2104}, mean: -1307861657.80021, std: 281698378.68003, params: {'n_estimators': 250, 'learning_rate': 0.2104}, mean: -1283597613.25266, std: 315484127.92213, params: {'n_estimators': 200, 'learning_rate': 0.21360000000000001}, mean: -1292848109.01324, std: 302695386.80809, params: {'n_estimators': 210, 'learning_rate': 0.21360000000000001}, mean: -1282008519.04949, std: 311196799.95733, params: {'n_estimators': 220, 'learning_rate': 0.21360000000000001}, mean: -1284678037.52664, std: 303673620.60049, params: {'n_estimators': 230, 'learning_rate': 0.21360000000000001}, mean: -1285706198.01549, std: 302227448.37593, params: {'n_estimators': 240, 'learning_rate': 0.21360000000000001}, mean: -1281043443.66594, std: 300842694.02526, params: {'n_estimators': 250, 'learning_rate': 0.21360000000000001}, mean: -1309676638.77099, std: 307377918.72918, params: {'n_estimators': 200, 'learning_rate': 0.21679999999999999}, mean: -1306034893.06245, std: 303047946.99120, params: {'n_estimators': 210, 'learning_rate': 0.21679999999999999}, mean: -1304334013.89952, std: 297356216.71324, params: {'n_estimators': 220, 'learning_rate': 0.21679999999999999}, mean: -1293672132.63377, std: 291790724.42618, params: {'n_estimators': 230, 'learning_rate': 0.21679999999999999}, mean: -1290770036.95794, std: 291838632.57369, params: {'n_estimators': 240, 'learning_rate': 0.21679999999999999}, mean: -1295529246.96001, std: 288712288.78054, params: {'n_estimators': 250, 'learning_rate': 0.21679999999999999}, mean: -1313601213.59299, std: 297008619.23027, params: {'n_estimators': 200, 'learning_rate': 0.22}, mean: -1314680328.09300, std: 295572000.66306, params: {'n_estimators': 210, 'learning_rate': 0.22}, mean: -1311710460.91269, std: 291891360.67007, params: {'n_estimators': 220, 'learning_rate': 0.22}, mean: -1311078004.35624, std: 282295858.32310, params: {'n_estimators': 230, 'learning_rate': 0.22}, mean: -1311680807.18114, std: 290771671.90962, params: {'n_estimators': 240, 'learning_rate': 0.22}, mean: -1315466170.93913, std: 297444606.06705, params: {'n_estimators': 250, 'learning_rate' ...
# Report best params
# ('score:', -1281043443.6659365)
# learning_rate: 0.21360000000000001
# n_estimators: 250
# Params for best estimator are  {'n_estimators': 250, 'loss': 'linear', 'base_estimator': None, 'random_state': 42, 'learning_rate': 0.21360000000000001}
# Now predict
# RMSE 0.219004246854
# Std:  69582.3518667  Mean:  187679.396996
# Min:  118283.593472  Max:  569959.183673
# Update param  n_estimators
# Best index is  5
# Arrived at end of search range  250
# Update param  learning_rate
# Best index is  3
# Params updated:  {'n_estimators': {'start': 200, 'end': 250, 'type': 'int'}, 'learning_rate': {'start': 0.2104, 'end': 0.21679999999999999, 'type': 'float'}}
# Go to next turn

# %%
from sklearn.ensemble import AdaBoostRegressor

print "Adaboost"
params={
    'n_estimators':{
        'start':410,
        'end':430,
        'type':'int'
    },
    'learning_rate':{
        'start':0.51,
        'end':0.55,
        'type':'float'
    }
}
abr = AdaBoostRegressor(loss='square',random_state=42)
auto_param_search(abr,params,2, X_train, y_train, X_test, y_test)
# Out:
# Adaboost
# 2  iterations of search for regressor
# <class 'sklearn.ensemble.weight_boosting.AdaBoostRegressor'>
# Starting param range is  {'n_estimators': {'start': 410, 'end': 430, 'type': 'int'}, 'learning_rate': {'start': 0.51, 'end': 0.55, 'type': 'float'}}
# This iteration is for params  {'n_estimators': {'start': 410, 'end': 430, 'type': 'int'}, 'learning_rate': {'start': 0.51, 'end': 0.55, 'type': 'float'}}
# Grinding param  n_estimators
# Grinding param  learning_rate
# Grinded params to  {'n_estimators': array([ 410.,  414.,  418.,  422.,  426.,  430.]), 'learning_rate': array([ 0.51 ,  0.518,  0.526,  0.534,  0.542,  0.55 ])}
# Rounding param  n_estimators with list  [ 410.  414.  418.  422.  426.  430.]
# Now rounded to  [410 414 418 422 426 430]
# Grinded params are rounded to  {'n_estimators': array([410, 414, 418, 422, 426, 430]), 'learning_rate': array([ 0.51 ,  0.518,  0.526,  0.534,  0.542,  0.55 ])}
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] n_estimators=410, learning_rate=0.51 ............................
# [CV] ................... n_estimators=410, learning_rate=0.51 -   4.6s
# [CV] n_estimators=410, learning_rate=0.51 ............................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    4.6s remaining:    0.0s
# [CV] ................... n_estimators=410, learning_rate=0.51 -   4.2s
# [CV] n_estimators=410, learning_rate=0.51 ............................
# [CV] ................... n_estimators=410, learning_rate=0.51 -   3.0s
# [CV] n_estimators=410, learning_rate=0.51 ............................
# [CV] ................... n_estimators=410, learning_rate=0.51 -   2.5s
# [CV] n_estimators=410, learning_rate=0.51 ............................
# [CV] ................... n_estimators=410, learning_rate=0.51 -   2.8s
# [CV] n_estimators=414, learning_rate=0.51 ............................
# [CV] ................... n_estimators=414, learning_rate=0.51 -   3.4s
# [CV] n_estimators=414, learning_rate=0.51 ............................
# [CV] ................... n_estimators=414, learning_rate=0.51 -   2.6s
# [CV] n_estimators=414, learning_rate=0.51 ............................
# [CV] ................... n_estimators=414, learning_rate=0.51 -   3.1s
# [CV] n_estimators=414, learning_rate=0.51 ............................
# [CV] ................... n_estimators=414, learning_rate=0.51 -   2.7s
# [CV] n_estimators=414, learning_rate=0.51 ............................
# [CV] ................... n_estimators=414, learning_rate=0.51 -   3.3s
# [CV] n_estimators=418, learning_rate=0.51 ............................
# [CV] ................... n_estimators=418, learning_rate=0.51 -   2.9s
# [CV] n_estimators=418, learning_rate=0.51 ............................
# [CV] ................... n_estimators=418, learning_rate=0.51 -   2.8s
# [CV] n_estimators=418, learning_rate=0.51 ............................
# [CV] ................... n_estimators=418, learning_rate=0.51 -   2.8s
# [CV] n_estimators=418, learning_rate=0.51 ............................
# [CV] ................... n_estimators=418, learning_rate=0.51 -   2.9s
# [CV] n_estimators=418, learning_rate=0.51 ............................
# [CV] ................... n_estimators=418, learning_rate=0.51 -   2.5s
# [CV] n_estimators=422, learning_rate=0.51 ............................
# [CV] ................... n_estimators=422, learning_rate=0.51 -   3.0s
# [CV] n_estimators=422, learning_rate=0.51 ............................
# [CV] ................... n_estimators=422, learning_rate=0.51 -   2.9s
# [CV] n_estimators=422, learning_rate=0.51 ............................
# [CV] ................... n_estimators=422, learning_rate=0.51 -   3.1s
# [CV] n_estimators=422, learning_rate=0.51 ............................
# [CV] ................... n_estimators=422, learning_rate=0.51 -   2.8s
# [CV] n_estimators=422, learning_rate=0.51 ............................
# [CV] ................... n_estimators=422, learning_rate=0.51 -   2.6s
# [CV] n_estimators=426, learning_rate=0.51 ............................
# [CV] ................... n_estimators=426, learning_rate=0.51 -   2.9s
# [CV] n_estimators=426, learning_rate=0.51 ............................
# [CV] ................... n_estimators=426, learning_rate=0.51 -   3.0s
# [CV] n_estimators=426, learning_rate=0.51 ............................
# [CV] ................... n_estimators=426, learning_rate=0.51 -   2.9s
# [CV] n_estimators=426, learning_rate=0.51 ............................
# [CV] ................... n_estimators=426, learning_rate=0.51 -   2.8s
# [CV] n_estimators=426, learning_rate=0.51 ............................
# [CV] ................... n_estimators=426, learning_rate=0.51 -   2.9s
# [CV] n_estimators=430, learning_rate=0.51 ............................
# [CV] ................... n_estimators=430, learning_rate=0.51 -   3.1s
# [CV] n_estimators=430, learning_rate=0.51 ............................
# [CV] ................... n_estimators=430, learning_rate=0.51 -   2.8s
# [CV] n_estimators=430, learning_rate=0.51 ............................
# [CV] ................... n_estimators=430, learning_rate=0.51 -   3.6s
# [CV] n_estimators=430, learning_rate=0.51 ............................
# [CV] ................... n_estimators=430, learning_rate=0.51 -   3.3s
# [CV] n_estimators=430, learning_rate=0.51 ............................
# [CV] ................... n_estimators=430, learning_rate=0.51 -   3.0s
# [CV] n_estimators=410, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.518 -   2.9s
# [CV] n_estimators=410, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.518 -   2.7s
# [CV] n_estimators=410, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.518 -   3.2s
# [CV] n_estimators=410, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.518 -   2.7s
# [CV] n_estimators=410, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.518 -   2.6s
# [CV] n_estimators=414, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=414, learning_rate=0.518 -   2.6s
# [CV] n_estimators=414, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=414, learning_rate=0.518 -   2.7s
# [CV] n_estimators=414, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=414, learning_rate=0.518 -   3.2s
# [CV] n_estimators=414, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=414, learning_rate=0.518 -   3.0s
# [CV] n_estimators=414, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=414, learning_rate=0.518 -   2.7s
# [CV] n_estimators=418, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.518 -   3.0s
# [CV] n_estimators=418, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.518 -   2.8s
# [CV] n_estimators=418, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.518 -   2.9s
# [CV] n_estimators=418, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.518 -   2.9s
# [CV] n_estimators=418, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.518 -   3.2s
# [CV] n_estimators=422, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=422, learning_rate=0.518 -   7.6s
# [CV] n_estimators=422, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=422, learning_rate=0.518 -  10.9s
# [CV] n_estimators=422, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=422, learning_rate=0.518 -   7.7s
# [CV] n_estimators=422, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=422, learning_rate=0.518 -   6.4s
# [CV] n_estimators=422, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=422, learning_rate=0.518 -   5.1s
# [CV] n_estimators=426, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=426, learning_rate=0.518 -   4.7s
# [CV] n_estimators=426, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=426, learning_rate=0.518 -   4.6s
# [CV] n_estimators=426, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=426, learning_rate=0.518 -   4.0s
# [CV] n_estimators=426, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=426, learning_rate=0.518 -   3.3s
# [CV] n_estimators=426, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=426, learning_rate=0.518 -   3.1s
# [CV] n_estimators=430, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=430, learning_rate=0.518 -   3.1s
# [CV] n_estimators=430, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=430, learning_rate=0.518 -   3.1s
# [CV] n_estimators=430, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=430, learning_rate=0.518 -   3.5s
# [CV] n_estimators=430, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=430, learning_rate=0.518 -   3.3s
# [CV] n_estimators=430, learning_rate=0.518 ...........................
# [CV] .................. n_estimators=430, learning_rate=0.518 -   3.1s
# [CV] n_estimators=410, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.526 -   2.7s
# [CV] n_estimators=410, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.526 -   3.0s
# [CV] n_estimators=410, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.526 -   3.4s
# [CV] n_estimators=410, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.526 -   3.6s
# [CV] n_estimators=410, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.526 -   2.6s
# [CV] n_estimators=414, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=414, learning_rate=0.526 -   3.6s
# [CV] n_estimators=414, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=414, learning_rate=0.526 -   3.5s
# [CV] n_estimators=414, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=414, learning_rate=0.526 -   3.2s
# [CV] n_estimators=414, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=414, learning_rate=0.526 -   3.4s
# [CV] n_estimators=414, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=414, learning_rate=0.526 -   3.6s
# [CV] n_estimators=418, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.526 -   3.9s
# [CV] n_estimators=418, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.526 -   3.8s
# [CV] n_estimators=418, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.526 -   3.8s
# [CV] n_estimators=418, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.526 -   3.3s
# [CV] n_estimators=418, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.526 -   3.2s
# [CV] n_estimators=422, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=422, learning_rate=0.526 -   3.2s
# [CV] n_estimators=422, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=422, learning_rate=0.526 -   2.8s
# [CV] n_estimators=422, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=422, learning_rate=0.526 -   3.0s
# [CV] n_estimators=422, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=422, learning_rate=0.526 -   2.9s
# [CV] n_estimators=422, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=422, learning_rate=0.526 -   2.8s
# [CV] n_estimators=426, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=426, learning_rate=0.526 -   3.1s
# [CV] n_estimators=426, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=426, learning_rate=0.526 -   2.8s
# [CV] n_estimators=426, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=426, learning_rate=0.526 -   3.4s
# [CV] n_estimators=426, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=426, learning_rate=0.526 -   2.5s
# [CV] n_estimators=426, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=426, learning_rate=0.526 -   3.2s
# [CV] n_estimators=430, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=430, learning_rate=0.526 -   4.3s
# [CV] n_estimators=430, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=430, learning_rate=0.526 -   3.8s
# [CV] n_estimators=430, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=430, learning_rate=0.526 -   4.2s
# [CV] n_estimators=430, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=430, learning_rate=0.526 -   3.6s
# [CV] n_estimators=430, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=430, learning_rate=0.526 -   3.2s
# [CV] n_estimators=410, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.534 -   3.9s
# [CV] n_estimators=410, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.534 -   3.4s
# [CV] n_estimators=410, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.534 -   3.7s
# [CV] n_estimators=410, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.534 -   2.8s
# [CV] n_estimators=410, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.534 -   2.6s
# [CV] n_estimators=414, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=414, learning_rate=0.534 -   3.1s
# [CV] n_estimators=414, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=414, learning_rate=0.534 -   3.0s
# [CV] n_estimators=414, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=414, learning_rate=0.534 -   2.6s
# [CV] n_estimators=414, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=414, learning_rate=0.534 -   2.9s
# [CV] n_estimators=414, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=414, learning_rate=0.534 -   3.0s
# [CV] n_estimators=418, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.534 -   2.6s
# [CV] n_estimators=418, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.534 -   3.0s
# [CV] n_estimators=418, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.534 -   2.8s
# [CV] n_estimators=418, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.534 -   3.1s
# [CV] n_estimators=418, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.534 -   2.7s
# [CV] n_estimators=422, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=422, learning_rate=0.534 -   2.9s
# [CV] n_estimators=422, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=422, learning_rate=0.534 -   3.0s
# [CV] n_estimators=422, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=422, learning_rate=0.534 -   3.5s
# [CV] n_estimators=422, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=422, learning_rate=0.534 -   3.1s
# [CV] n_estimators=422, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=422, learning_rate=0.534 -   3.0s
# [CV] n_estimators=426, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=426, learning_rate=0.534 -   3.0s
# [CV] n_estimators=426, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=426, learning_rate=0.534 -   3.2s
# [CV] n_estimators=426, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=426, learning_rate=0.534 -   3.0s
# [CV] n_estimators=426, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=426, learning_rate=0.534 -   2.8s
# [CV] n_estimators=426, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=426, learning_rate=0.534 -   2.8s
# [CV] n_estimators=430, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=430, learning_rate=0.534 -   2.8s
# [CV] n_estimators=430, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=430, learning_rate=0.534 -   3.1s
# [CV] n_estimators=430, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=430, learning_rate=0.534 -   2.6s
# [CV] n_estimators=430, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=430, learning_rate=0.534 -   3.2s
# [CV] n_estimators=430, learning_rate=0.534 ...........................
# [CV] .................. n_estimators=430, learning_rate=0.534 -   2.7s
# [CV] n_estimators=410, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.542 -   3.1s
# [CV] n_estimators=410, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.542 -   2.5s
# [CV] n_estimators=410, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.542 -   2.6s
# [CV] n_estimators=410, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.542 -   2.6s
# [CV] n_estimators=410, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.542 -   2.5s
# [CV] n_estimators=414, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=414, learning_rate=0.542 -   2.7s
# [CV] n_estimators=414, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=414, learning_rate=0.542 -   2.7s
# [CV] n_estimators=414, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=414, learning_rate=0.542 -   2.9s
# [CV] n_estimators=414, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=414, learning_rate=0.542 -   3.5s
# [CV] n_estimators=414, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=414, learning_rate=0.542 -   3.0s
# [CV] n_estimators=418, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.542 -   3.2s
# [CV] n_estimators=418, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.542 -   2.7s
# [CV] n_estimators=418, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.542 -   2.6s
# [CV] n_estimators=418, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.542 -   2.8s
# [CV] n_estimators=418, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.542 -   3.0s
# [CV] n_estimators=422, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=422, learning_rate=0.542 -   2.7s
# [CV] n_estimators=422, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=422, learning_rate=0.542 -   3.1s
# [CV] n_estimators=422, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=422, learning_rate=0.542 -   3.4s
# [CV] n_estimators=422, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=422, learning_rate=0.542 -   2.8s
# [CV] n_estimators=422, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=422, learning_rate=0.542 -   2.9s
# [CV] n_estimators=426, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=426, learning_rate=0.542 -   3.0s
# [CV] n_estimators=426, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=426, learning_rate=0.542 -   3.9s
# [CV] n_estimators=426, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=426, learning_rate=0.542 -   2.7s
# [CV] n_estimators=426, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=426, learning_rate=0.542 -   2.8s
# [CV] n_estimators=426, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=426, learning_rate=0.542 -   2.8s
# [CV] n_estimators=430, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=430, learning_rate=0.542 -   3.4s
# [CV] n_estimators=430, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=430, learning_rate=0.542 -   3.1s
# [CV] n_estimators=430, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=430, learning_rate=0.542 -   2.8s
# [CV] n_estimators=430, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=430, learning_rate=0.542 -   2.8s
# [CV] n_estimators=430, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=430, learning_rate=0.542 -   3.4s
# [CV] n_estimators=410, learning_rate=0.55 ............................
# [CV] ................... n_estimators=410, learning_rate=0.55 -   3.4s
# [CV] n_estimators=410, learning_rate=0.55 ............................
# [CV] ................... n_estimators=410, learning_rate=0.55 -   2.9s
# [CV] n_estimators=410, learning_rate=0.55 ............................
# [CV] ................... n_estimators=410, learning_rate=0.55 -   3.1s
# [CV] n_estimators=410, learning_rate=0.55 ............................
# [CV] ................... n_estimators=410, learning_rate=0.55 -   2.6s
# [CV] n_estimators=410, learning_rate=0.55 ............................
# [CV] ................... n_estimators=410, learning_rate=0.55 -   2.8s
# [CV] n_estimators=414, learning_rate=0.55 ............................
# [CV] ................... n_estimators=414, learning_rate=0.55 -   3.5s
# [CV] n_estimators=414, learning_rate=0.55 ............................
# [CV] ................... n_estimators=414, learning_rate=0.55 -   2.7s
# [CV] n_estimators=414, learning_rate=0.55 ............................
# [CV] ................... n_estimators=414, learning_rate=0.55 -   3.0s
# [CV] n_estimators=414, learning_rate=0.55 ............................
# [CV] ................... n_estimators=414, learning_rate=0.55 -   3.1s
# [CV] n_estimators=414, learning_rate=0.55 ............................
# [CV] ................... n_estimators=414, learning_rate=0.55 -   2.8s
# [CV] n_estimators=418, learning_rate=0.55 ............................
# [CV] ................... n_estimators=418, learning_rate=0.55 -   2.8s
# [CV] n_estimators=418, learning_rate=0.55 ............................
# [CV] ................... n_estimators=418, learning_rate=0.55 -   2.9s
# [CV] n_estimators=418, learning_rate=0.55 ............................
# [CV] ................... n_estimators=418, learning_rate=0.55 -   2.9s
# [CV] n_estimators=418, learning_rate=0.55 ............................
# [CV] ................... n_estimators=418, learning_rate=0.55 -   3.1s
# [CV] n_estimators=418, learning_rate=0.55 ............................
# [CV] ................... n_estimators=418, learning_rate=0.55 -   2.6s
# [CV] n_estimators=422, learning_rate=0.55 ............................
# [CV] ................... n_estimators=422, learning_rate=0.55 -   2.7s
# [CV] n_estimators=422, learning_rate=0.55 ............................
# [CV] ................... n_estimators=422, learning_rate=0.55 -   3.0s
# [CV] n_estimators=422, learning_rate=0.55 ............................
# [CV] ................... n_estimators=422, learning_rate=0.55 -   2.6s
# [CV] n_estimators=422, learning_rate=0.55 ............................
# [CV] ................... n_estimators=422, learning_rate=0.55 -   2.6s
# [CV] n_estimators=422, learning_rate=0.55 ............................
# [CV] ................... n_estimators=422, learning_rate=0.55 -   3.0s
# [CV] n_estimators=426, learning_rate=0.55 ............................
# [CV] ................... n_estimators=426, learning_rate=0.55 -   2.6s
# [CV] n_estimators=426, learning_rate=0.55 ............................
# [CV] ................... n_estimators=426, learning_rate=0.55 -   3.1s
# [CV] n_estimators=426, learning_rate=0.55 ............................
# [CV] ................... n_estimators=426, learning_rate=0.55 -   3.4s
# [CV] n_estimators=426, learning_rate=0.55 ............................
# [CV] ................... n_estimators=426, learning_rate=0.55 -   2.9s
# [CV] n_estimators=426, learning_rate=0.55 ............................
# [CV] ................... n_estimators=426, learning_rate=0.55 -   2.5s
# [CV] n_estimators=430, learning_rate=0.55 ............................
# [CV] ................... n_estimators=430, learning_rate=0.55 -   2.8s
# [CV] n_estimators=430, learning_rate=0.55 ............................
# [CV] ................... n_estimators=430, learning_rate=0.55 -   2.8s
# [CV] n_estimators=430, learning_rate=0.55 ............................
# [CV] ................... n_estimators=430, learning_rate=0.55 -   2.7s
# [CV] n_estimators=430, learning_rate=0.55 ............................
# [CV] ................... n_estimators=430, learning_rate=0.55 -   3.3s
# [CV] n_estimators=430, learning_rate=0.55 ............................
# [CV] ................... n_estimators=430, learning_rate=0.55 -   2.8s
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed:  9.8min finished
# Report scores
# [mean: -1469428458.95993, std: 338933196.42646, params: {'n_estimators': 410, 'learning_rate': 0.51000000000000001}, mean: -1468826906.67707, std: 340382659.86337, params: {'n_estimators': 414, 'learning_rate': 0.51000000000000001}, mean: -1471734183.23518, std: 338507600.59344, params: {'n_estimators': 418, 'learning_rate': 0.51000000000000001}, mean: -1469584535.75009, std: 339696800.96096, params: {'n_estimators': 422, 'learning_rate': 0.51000000000000001}, mean: -1468426056.96934, std: 340230386.25714, params: {'n_estimators': 426, 'learning_rate': 0.51000000000000001}, mean: -1471657801.40158, std: 341917796.63949, params: {'n_estimators': 430, 'learning_rate': 0.51000000000000001}, mean: -1468280786.78368, std: 302335559.33452, params: {'n_estimators': 410, 'learning_rate': 0.51800000000000002}, mean: -1469022698.44653, std: 305380893.52294, params: {'n_estimators': 414, 'learning_rate': 0.51800000000000002}, mean: -1468580760.25116, std: 304301507.37885, params: {'n_estimators': 418, 'learning_rate': 0.51800000000000002}, mean: -1469949455.20038, std: 303909255.28323, params: {'n_estimators': 422, 'learning_rate': 0.51800000000000002}, mean: -1470772879.09984, std: 304108886.27318, params: {'n_estimators': 426, 'learning_rate': 0.51800000000000002}, mean: -1474571765.43456, std: 299938085.90058, params: {'n_estimators': 430, 'learning_rate': 0.51800000000000002}, mean: -1460170138.69875, std: 313553942.16541, params: {'n_estimators': 410, 'learning_rate': 0.52600000000000002}, mean: -1461511864.79547, std: 308343336.91160, params: {'n_estimators': 414, 'learning_rate': 0.52600000000000002}, mean: -1464716300.25976, std: 310391345.34493, params: {'n_estimators': 418, 'learning_rate': 0.52600000000000002}, mean: -1465267591.75163, std: 308288525.06005, params: {'n_estimators': 422, 'learning_rate': 0.52600000000000002}, mean: -1463214931.77897, std: 306706970.15700, params: {'n_estimators': 426, 'learning_rate': 0.52600000000000002}, mean: -1463549001.52047, std: 307657871.28610, params: {'n_estimators': 430, 'learning_rate': 0.52600000000000002}, mean: -1451357195.75318, std: 343069115.43537, params: {'n_estimators': 410, 'learning_rate': 0.53400000000000003}, mean: -1448174130.14621, std: 342843308.69232, params: {'n_estimators': 414, 'learning_rate': 0.53400000000000003}, mean: -1449421481.73556, std: 338570781.37302, params: {'n_estimators': 418, 'learning_rate': 0.53400000000000003}, mean: -1453642203.09871, std: 340153126.16909, params: {'n_estimators': 422, 'learning_rate': 0.53400000000000003}, mean: -1453145296.40561, std: 340330521.93097, params: {'n_estimators': 426, 'learning_rate': 0.53400000000000003}, mean: -1454866097.85172, std: 340806815.06837, params: {'n_estimators': 430, 'learning_rate': 0.53400000000000003}, mean: -1475406664.97288, std: 329073230.32597, params: {'n_estimators': 410, 'learning_rate': 0.54200000000000004}, mean: -1478099089.65477, std: 328583759.68076, params: {'n_estimators': 414, 'learning_rate': 0.54200000000000004}, mean: -1479717697.76359, std: 326258849.78756, params: {'n_estimators': 418, 'learning_rate': 0.54200000000000004}, mean: -1478240819.62603, std: 322331648.21586, params: {'n_estimators': 422, 'learning_rate': 0.54200000000000004}, mean: -1477306291.37055, std: 321416741.66516, params: {'n_estimators': 426, 'learning_rate': 0.54200000000000004}, mean: -1478447485.35332, std: 324104033.28622, params: {'n_estimators': 430, 'learning_rate': 0.54200000000000004}, mean: -1511042898.67616, std: 335555361.15212, params: {'n_estimators': 410, 'learning_rate': 0.55000000000000004}, mean: -1512623641.08259, std: 338881042.46055, params: {'n_estimators': 414, 'learning_rate': 0.55000000000000004}, mean: -1511124589.91171, std: 337681315.74654, params: {'n_estimators': 418, 'learning_rate': 0.55000000000000004}, mean: -1507310340.05880, std: 334907993.33188, params: {'n_estimators': 422, 'learning_rate': 0.55000000000000004}, mean: -1505599940.45783, std: 339878314.00557, params:  ...
# Report best params
# ('score:', -1448174130.146208)
# learning_rate: 0.53400000000000003
# n_estimators: 414
# Params for best estimator are  {'n_estimators': 414, 'loss': 'square', 'base_estimator': None, 'random_state': 42, 'learning_rate': 0.53400000000000003}
# Now predict
# RMSE 0.243107211809
# Std:  67861.3647671  Mean:  192718.467348
# Min:  125717.656388  Max:  582237.288136
# Update param  n_estimators
# Best index is  1
# Update param  learning_rate
# Best index is  3
# Params updated:  {'n_estimators': {'start': 410, 'end': 418, 'type': 'int'}, 'learning_rate': {'start': 0.52600000000000002, 'end': 0.54200000000000004, 'type': 'float'}}
# Go to next turn
# This iteration is for params  {'n_estimators': {'start': 410, 'end': 418, 'type': 'int'}, 'learning_rate': {'start': 0.52600000000000002, 'end': 0.54200000000000004, 'type': 'float'}}
# Grinding param  n_estimators
# Grinding param  learning_rate
# Grinded params to  {'n_estimators': array([ 410. ,  411.6,  413.2,  414.8,  416.4,  418. ]), 'learning_rate': array([ 0.526 ,  0.5292,  0.5324,  0.5356,  0.5388,  0.542 ])}
# Rounding param  n_estimators with list  [ 410.   411.6  413.2  414.8  416.4  418. ]
# Now rounded to  [410 412 413 415 416 418]
# Grinded params are rounded to  {'n_estimators': array([410, 412, 413, 415, 416, 418]), 'learning_rate': array([ 0.526 ,  0.5292,  0.5324,  0.5356,  0.5388,  0.542 ])}
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] n_estimators=410, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.526 -   2.8s
# [CV] n_estimators=410, learning_rate=0.526 ...........................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.8s remaining:    0.0s
# [CV] .................. n_estimators=410, learning_rate=0.526 -   3.0s
# [CV] n_estimators=410, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.526 -   2.8s
# [CV] n_estimators=410, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.526 -   3.1s
# [CV] n_estimators=410, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.526 -   3.4s
# [CV] n_estimators=412, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=412, learning_rate=0.526 -   3.6s
# [CV] n_estimators=412, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=412, learning_rate=0.526 -   4.9s
# [CV] n_estimators=412, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=412, learning_rate=0.526 -   4.5s
# [CV] n_estimators=412, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=412, learning_rate=0.526 -   3.5s
# [CV] n_estimators=412, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=412, learning_rate=0.526 -   3.9s
# [CV] n_estimators=413, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=413, learning_rate=0.526 -   3.9s
# [CV] n_estimators=413, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=413, learning_rate=0.526 -   3.7s
# [CV] n_estimators=413, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=413, learning_rate=0.526 -   3.0s
# [CV] n_estimators=413, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=413, learning_rate=0.526 -   3.0s
# [CV] n_estimators=413, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=413, learning_rate=0.526 -   3.2s
# [CV] n_estimators=415, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=415, learning_rate=0.526 -   3.3s
# [CV] n_estimators=415, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=415, learning_rate=0.526 -   3.2s
# [CV] n_estimators=415, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=415, learning_rate=0.526 -   2.8s
# [CV] n_estimators=415, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=415, learning_rate=0.526 -   2.9s
# [CV] n_estimators=415, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=415, learning_rate=0.526 -   2.7s
# [CV] n_estimators=416, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=416, learning_rate=0.526 -   2.6s
# [CV] n_estimators=416, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=416, learning_rate=0.526 -   3.2s
# [CV] n_estimators=416, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=416, learning_rate=0.526 -   3.0s
# [CV] n_estimators=416, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=416, learning_rate=0.526 -   2.8s
# [CV] n_estimators=416, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=416, learning_rate=0.526 -   3.2s
# [CV] n_estimators=418, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.526 -   2.7s
# [CV] n_estimators=418, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.526 -   2.7s
# [CV] n_estimators=418, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.526 -   2.9s
# [CV] n_estimators=418, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.526 -   2.5s
# [CV] n_estimators=418, learning_rate=0.526 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.526 -   2.9s
# [CV] n_estimators=410, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=410, learning_rate=0.5292 -   2.6s
# [CV] n_estimators=410, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=410, learning_rate=0.5292 -   2.8s
# [CV] n_estimators=410, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=410, learning_rate=0.5292 -   2.9s
# [CV] n_estimators=410, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=410, learning_rate=0.5292 -   2.5s
# [CV] n_estimators=410, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=410, learning_rate=0.5292 -   2.7s
# [CV] n_estimators=412, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=412, learning_rate=0.5292 -   2.7s
# [CV] n_estimators=412, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=412, learning_rate=0.5292 -   3.1s
# [CV] n_estimators=412, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=412, learning_rate=0.5292 -   2.9s
# [CV] n_estimators=412, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=412, learning_rate=0.5292 -   3.0s
# [CV] n_estimators=412, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=412, learning_rate=0.5292 -   2.5s
# [CV] n_estimators=413, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=413, learning_rate=0.5292 -   3.1s
# [CV] n_estimators=413, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=413, learning_rate=0.5292 -   2.5s
# [CV] n_estimators=413, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=413, learning_rate=0.5292 -   3.0s
# [CV] n_estimators=413, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=413, learning_rate=0.5292 -   2.4s
# [CV] n_estimators=413, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=413, learning_rate=0.5292 -   2.6s
# [CV] n_estimators=415, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=415, learning_rate=0.5292 -   2.8s
# [CV] n_estimators=415, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=415, learning_rate=0.5292 -   2.8s
# [CV] n_estimators=415, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=415, learning_rate=0.5292 -   2.5s
# [CV] n_estimators=415, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=415, learning_rate=0.5292 -   2.7s
# [CV] n_estimators=415, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=415, learning_rate=0.5292 -   2.8s
# [CV] n_estimators=416, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=416, learning_rate=0.5292 -   2.9s
# [CV] n_estimators=416, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=416, learning_rate=0.5292 -   2.9s
# [CV] n_estimators=416, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=416, learning_rate=0.5292 -   2.6s
# [CV] n_estimators=416, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=416, learning_rate=0.5292 -   3.2s
# [CV] n_estimators=416, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=416, learning_rate=0.5292 -   2.6s
# [CV] n_estimators=418, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=418, learning_rate=0.5292 -   3.1s
# [CV] n_estimators=418, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=418, learning_rate=0.5292 -   2.7s
# [CV] n_estimators=418, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=418, learning_rate=0.5292 -   2.7s
# [CV] n_estimators=418, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=418, learning_rate=0.5292 -   2.7s
# [CV] n_estimators=418, learning_rate=0.5292 ..........................
# [CV] ................. n_estimators=418, learning_rate=0.5292 -   2.5s
# [CV] n_estimators=410, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=410, learning_rate=0.5324 -   2.9s
# [CV] n_estimators=410, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=410, learning_rate=0.5324 -   2.7s
# [CV] n_estimators=410, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=410, learning_rate=0.5324 -   2.7s
# [CV] n_estimators=410, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=410, learning_rate=0.5324 -   2.4s
# [CV] n_estimators=410, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=410, learning_rate=0.5324 -   2.9s
# [CV] n_estimators=412, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=412, learning_rate=0.5324 -   2.6s
# [CV] n_estimators=412, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=412, learning_rate=0.5324 -   2.9s
# [CV] n_estimators=412, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=412, learning_rate=0.5324 -   2.6s
# [CV] n_estimators=412, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=412, learning_rate=0.5324 -   3.2s
# [CV] n_estimators=412, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=412, learning_rate=0.5324 -   2.6s
# [CV] n_estimators=413, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=413, learning_rate=0.5324 -   2.6s
# [CV] n_estimators=413, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=413, learning_rate=0.5324 -   2.6s
# [CV] n_estimators=413, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=413, learning_rate=0.5324 -   2.4s
# [CV] n_estimators=413, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=413, learning_rate=0.5324 -   2.5s
# [CV] n_estimators=413, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=413, learning_rate=0.5324 -   2.9s
# [CV] n_estimators=415, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=415, learning_rate=0.5324 -   2.8s
# [CV] n_estimators=415, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=415, learning_rate=0.5324 -   3.0s
# [CV] n_estimators=415, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=415, learning_rate=0.5324 -   2.6s
# [CV] n_estimators=415, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=415, learning_rate=0.5324 -   3.0s
# [CV] n_estimators=415, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=415, learning_rate=0.5324 -   3.0s
# [CV] n_estimators=416, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=416, learning_rate=0.5324 -   2.6s
# [CV] n_estimators=416, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=416, learning_rate=0.5324 -   2.6s
# [CV] n_estimators=416, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=416, learning_rate=0.5324 -   2.8s
# [CV] n_estimators=416, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=416, learning_rate=0.5324 -   2.7s
# [CV] n_estimators=416, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=416, learning_rate=0.5324 -   2.8s
# [CV] n_estimators=418, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=418, learning_rate=0.5324 -   2.7s
# [CV] n_estimators=418, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=418, learning_rate=0.5324 -   2.5s
# [CV] n_estimators=418, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=418, learning_rate=0.5324 -   2.8s
# [CV] n_estimators=418, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=418, learning_rate=0.5324 -   2.9s
# [CV] n_estimators=418, learning_rate=0.5324 ..........................
# [CV] ................. n_estimators=418, learning_rate=0.5324 -   2.6s
# [CV] n_estimators=410, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=410, learning_rate=0.5356 -   2.5s
# [CV] n_estimators=410, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=410, learning_rate=0.5356 -   2.5s
# [CV] n_estimators=410, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=410, learning_rate=0.5356 -   3.0s
# [CV] n_estimators=410, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=410, learning_rate=0.5356 -   2.8s
# [CV] n_estimators=410, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=410, learning_rate=0.5356 -   2.9s
# [CV] n_estimators=412, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=412, learning_rate=0.5356 -   2.5s
# [CV] n_estimators=412, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=412, learning_rate=0.5356 -   2.6s
# [CV] n_estimators=412, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=412, learning_rate=0.5356 -   2.8s
# [CV] n_estimators=412, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=412, learning_rate=0.5356 -   3.2s
# [CV] n_estimators=412, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=412, learning_rate=0.5356 -   2.7s
# [CV] n_estimators=413, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=413, learning_rate=0.5356 -   2.9s
# [CV] n_estimators=413, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=413, learning_rate=0.5356 -   2.9s
# [CV] n_estimators=413, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=413, learning_rate=0.5356 -   2.9s
# [CV] n_estimators=413, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=413, learning_rate=0.5356 -   2.5s
# [CV] n_estimators=413, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=413, learning_rate=0.5356 -   2.6s
# [CV] n_estimators=415, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=415, learning_rate=0.5356 -   3.4s
# [CV] n_estimators=415, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=415, learning_rate=0.5356 -   2.9s
# [CV] n_estimators=415, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=415, learning_rate=0.5356 -   2.6s
# [CV] n_estimators=415, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=415, learning_rate=0.5356 -   2.7s
# [CV] n_estimators=415, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=415, learning_rate=0.5356 -   2.8s
# [CV] n_estimators=416, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=416, learning_rate=0.5356 -   2.7s
# [CV] n_estimators=416, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=416, learning_rate=0.5356 -   3.6s
# [CV] n_estimators=416, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=416, learning_rate=0.5356 -   4.6s
# [CV] n_estimators=416, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=416, learning_rate=0.5356 -   4.5s
# [CV] n_estimators=416, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=416, learning_rate=0.5356 -   4.2s
# [CV] n_estimators=418, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=418, learning_rate=0.5356 -   4.0s
# [CV] n_estimators=418, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=418, learning_rate=0.5356 -   3.8s
# [CV] n_estimators=418, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=418, learning_rate=0.5356 -   4.9s
# [CV] n_estimators=418, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=418, learning_rate=0.5356 -   3.0s
# [CV] n_estimators=418, learning_rate=0.5356 ..........................
# [CV] ................. n_estimators=418, learning_rate=0.5356 -   2.7s
# [CV] n_estimators=410, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=410, learning_rate=0.5388 -   2.7s
# [CV] n_estimators=410, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=410, learning_rate=0.5388 -   2.5s
# [CV] n_estimators=410, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=410, learning_rate=0.5388 -   3.3s
# [CV] n_estimators=410, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=410, learning_rate=0.5388 -   2.5s
# [CV] n_estimators=410, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=410, learning_rate=0.5388 -   2.8s
# [CV] n_estimators=412, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=412, learning_rate=0.5388 -   2.4s
# [CV] n_estimators=412, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=412, learning_rate=0.5388 -   2.5s
# [CV] n_estimators=412, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=412, learning_rate=0.5388 -   3.1s
# [CV] n_estimators=412, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=412, learning_rate=0.5388 -   2.6s
# [CV] n_estimators=412, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=412, learning_rate=0.5388 -   3.1s
# [CV] n_estimators=413, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=413, learning_rate=0.5388 -   2.6s
# [CV] n_estimators=413, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=413, learning_rate=0.5388 -   2.5s
# [CV] n_estimators=413, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=413, learning_rate=0.5388 -   2.7s
# [CV] n_estimators=413, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=413, learning_rate=0.5388 -   2.8s
# [CV] n_estimators=413, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=413, learning_rate=0.5388 -   2.8s
# [CV] n_estimators=415, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=415, learning_rate=0.5388 -   2.8s
# [CV] n_estimators=415, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=415, learning_rate=0.5388 -   2.8s
# [CV] n_estimators=415, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=415, learning_rate=0.5388 -   2.8s
# [CV] n_estimators=415, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=415, learning_rate=0.5388 -   2.6s
# [CV] n_estimators=415, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=415, learning_rate=0.5388 -   2.7s
# [CV] n_estimators=416, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=416, learning_rate=0.5388 -   2.6s
# [CV] n_estimators=416, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=416, learning_rate=0.5388 -   2.6s
# [CV] n_estimators=416, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=416, learning_rate=0.5388 -   3.4s
# [CV] n_estimators=416, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=416, learning_rate=0.5388 -   3.4s
# [CV] n_estimators=416, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=416, learning_rate=0.5388 -   3.8s
# [CV] n_estimators=418, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=418, learning_rate=0.5388 -   3.0s
# [CV] n_estimators=418, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=418, learning_rate=0.5388 -   3.8s
# [CV] n_estimators=418, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=418, learning_rate=0.5388 -   3.6s
# [CV] n_estimators=418, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=418, learning_rate=0.5388 -   3.0s
# [CV] n_estimators=418, learning_rate=0.5388 ..........................
# [CV] ................. n_estimators=418, learning_rate=0.5388 -   2.7s
# [CV] n_estimators=410, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.542 -   2.9s
# [CV] n_estimators=410, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.542 -   3.0s
# [CV] n_estimators=410, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.542 -   3.3s
# [CV] n_estimators=410, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.542 -   2.6s
# [CV] n_estimators=410, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=410, learning_rate=0.542 -   2.7s
# [CV] n_estimators=412, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=412, learning_rate=0.542 -   2.7s
# [CV] n_estimators=412, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=412, learning_rate=0.542 -   2.6s
# [CV] n_estimators=412, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=412, learning_rate=0.542 -   2.9s
# [CV] n_estimators=412, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=412, learning_rate=0.542 -   2.6s
# [CV] n_estimators=412, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=412, learning_rate=0.542 -   2.6s
# [CV] n_estimators=413, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=413, learning_rate=0.542 -   2.9s
# [CV] n_estimators=413, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=413, learning_rate=0.542 -   2.6s
# [CV] n_estimators=413, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=413, learning_rate=0.542 -   2.8s
# [CV] n_estimators=413, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=413, learning_rate=0.542 -   2.5s
# [CV] n_estimators=413, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=413, learning_rate=0.542 -   2.6s
# [CV] n_estimators=415, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=415, learning_rate=0.542 -   2.6s
# [CV] n_estimators=415, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=415, learning_rate=0.542 -   2.5s
# [CV] n_estimators=415, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=415, learning_rate=0.542 -   2.7s
# [CV] n_estimators=415, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=415, learning_rate=0.542 -   2.6s
# [CV] n_estimators=415, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=415, learning_rate=0.542 -   2.5s
# [CV] n_estimators=416, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=416, learning_rate=0.542 -   2.5s
# [CV] n_estimators=416, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=416, learning_rate=0.542 -   2.9s
# [CV] n_estimators=416, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=416, learning_rate=0.542 -   2.8s
# [CV] n_estimators=416, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=416, learning_rate=0.542 -   3.2s
# [CV] n_estimators=416, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=416, learning_rate=0.542 -   2.6s
# [CV] n_estimators=418, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.542 -   2.8s
# [CV] n_estimators=418, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.542 -   2.7s
# [CV] n_estimators=418, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.542 -   2.5s
# [CV] n_estimators=418, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.542 -   2.7s
# [CV] n_estimators=418, learning_rate=0.542 ...........................
# [CV] .................. n_estimators=418, learning_rate=0.542 -   2.6s
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed:  9.0min finished
# Report scores
# [mean: -1460170138.69875, std: 313553942.16541, params: {'n_estimators': 410, 'learning_rate': 0.52600000000000002}, mean: -1460507439.86060, std: 310825775.66846, params: {'n_estimators': 412, 'learning_rate': 0.52600000000000002}, mean: -1461360745.79443, std: 310218272.25638, params: {'n_estimators': 413, 'learning_rate': 0.52600000000000002}, mean: -1462670497.94405, std: 309392837.49819, params: {'n_estimators': 415, 'learning_rate': 0.52600000000000002}, mean: -1460336028.57954, std: 309391869.97607, params: {'n_estimators': 416, 'learning_rate': 0.52600000000000002}, mean: -1464716300.25976, std: 310391345.34493, params: {'n_estimators': 418, 'learning_rate': 0.52600000000000002}, mean: -1490663463.30268, std: 352262664.75402, params: {'n_estimators': 410, 'learning_rate': 0.5292}, mean: -1490409301.94912, std: 353544135.96490, params: {'n_estimators': 412, 'learning_rate': 0.5292}, mean: -1491254514.43356, std: 353966689.74344, params: {'n_estimators': 413, 'learning_rate': 0.5292}, mean: -1488694506.30425, std: 355547798.84285, params: {'n_estimators': 415, 'learning_rate': 0.5292}, mean: -1489541348.09398, std: 355548570.16164, params: {'n_estimators': 416, 'learning_rate': 0.5292}, mean: -1490211754.90604, std: 359710893.29786, params: {'n_estimators': 418, 'learning_rate': 0.5292}, mean: -1465001684.66386, std: 327225486.85926, params: {'n_estimators': 410, 'learning_rate': 0.53239999999999998}, mean: -1467365175.72026, std: 330443851.79506, params: {'n_estimators': 412, 'learning_rate': 0.53239999999999998}, mean: -1463794948.40349, std: 331838513.12449, params: {'n_estimators': 413, 'learning_rate': 0.53239999999999998}, mean: -1464282747.66274, std: 334847456.81185, params: {'n_estimators': 415, 'learning_rate': 0.53239999999999998}, mean: -1464496218.77409, std: 330889857.39748, params: {'n_estimators': 416, 'learning_rate': 0.53239999999999998}, mean: -1466358948.55109, std: 331375190.15316, params: {'n_estimators': 418, 'learning_rate': 0.53239999999999998}, mean: -1460647390.57438, std: 310264595.85161, params: {'n_estimators': 410, 'learning_rate': 0.53560000000000008}, mean: -1463495174.57704, std: 308389996.35616, params: {'n_estimators': 412, 'learning_rate': 0.53560000000000008}, mean: -1467014736.92431, std: 310288409.43325, params: {'n_estimators': 413, 'learning_rate': 0.53560000000000008}, mean: -1465013471.70134, std: 311961945.36825, params: {'n_estimators': 415, 'learning_rate': 0.53560000000000008}, mean: -1462722373.50289, std: 311007160.95153, params: {'n_estimators': 416, 'learning_rate': 0.53560000000000008}, mean: -1461431435.77905, std: 308399712.26901, params: {'n_estimators': 418, 'learning_rate': 0.53560000000000008}, mean: -1490955704.13500, std: 354559893.21190, params: {'n_estimators': 410, 'learning_rate': 0.53880000000000006}, mean: -1486838486.24543, std: 354021330.64313, params: {'n_estimators': 412, 'learning_rate': 0.53880000000000006}, mean: -1484296262.36491, std: 352713071.79692, params: {'n_estimators': 413, 'learning_rate': 0.53880000000000006}, mean: -1485084391.03259, std: 354968270.58706, params: {'n_estimators': 415, 'learning_rate': 0.53880000000000006}, mean: -1487813883.63826, std: 354935802.79498, params: {'n_estimators': 416, 'learning_rate': 0.53880000000000006}, mean: -1486645455.83453, std: 358250238.26378, params: {'n_estimators': 418, 'learning_rate': 0.53880000000000006}, mean: -1475406664.97288, std: 329073230.32597, params: {'n_estimators': 410, 'learning_rate': 0.54200000000000004}, mean: -1476090272.68256, std: 327717838.65542, params: {'n_estimators': 412, 'learning_rate': 0.54200000000000004}, mean: -1476786933.99471, std: 328135302.92715, params: {'n_estimators': 413, 'learning_rate': 0.54200000000000004}, mean: -1478910132.41963, std: 327741844.17461, params: {'n_estimators': 415, 'learning_rate': 0.54200000000000004}, mean: -1479705195.06709, std: 327539423.34821, params: {'n_estimators': 416, 'learning_rate': 0.54200000000000004}, mean: -1479717697 ...
# Report best params
# ('score:', -1460170138.6987522)
# learning_rate: 0.52600000000000002
# n_estimators: 410
# Params for best estimator are  {'n_estimators': 410, 'loss': 'square', 'base_estimator': None, 'random_state': 42, 'learning_rate': 0.52600000000000002}
# Now predict
# RMSE 0.242388228106
# Std:  68931.3581224  Mean:  192734.220448
# Min:  125073.102151  Max:  595000.0
# Update param  n_estimators
# Best index is  0
# Arrived at start of search range  410
# Update param  learning_rate
# Best index is  0
# Arrived at start of search range  0.526
# Params updated:  {'n_estimators': {'start': 410, 'end': 418, 'type': 'int'}, 'learning_rate': {'start': 0.52600000000000002, 'end': 0.54200000000000004, 'type': 'float'}}
# Go to next turn

# %%
from sklearn.ensemble import AdaBoostRegressor

print "Adaboost"
params={
    'n_estimators':{
        'start':158,
        'end':174,
        'type':'int'
    },
    'learning_rate':{
        'start':0.33,
        'end':0.35,
        'type':'float'
    }
}
abr2 = AdaBoostRegressor(loss='exponential',random_state=42)
auto_param_search(abr2,params,1, X_train, y_train, X_test, y_test)
# Out:
# Adaboost
# 1  iterations of search for regressor
# <class 'sklearn.ensemble.weight_boosting.AdaBoostRegressor'>
# Starting param range is  {'n_estimators': {'start': 158, 'end': 174, 'type': 'int'}, 'learning_rate': {'start': 0.33, 'end': 0.35, 'type': 'float'}}
# This iteration is for params  {'n_estimators': {'start': 158, 'end': 174, 'type': 'int'}, 'learning_rate': {'start': 0.33, 'end': 0.35, 'type': 'float'}}
# Grinding param  n_estimators
# Grinding param  learning_rate
# Grinded params to  {'n_estimators': array([ 158. ,  161.2,  164.4,  167.6,  170.8,  174. ]), 'learning_rate': array([ 0.33 ,  0.334,  0.338,  0.342,  0.346,  0.35 ])}
# Rounding param  n_estimators with list  [ 158.   161.2  164.4  167.6  170.8  174. ]
# Now rounded to  [158 161 164 168 171 174]
# Grinded params are rounded to  {'n_estimators': array([158, 161, 164, 168, 171, 174]), 'learning_rate': array([ 0.33 ,  0.334,  0.338,  0.342,  0.346,  0.35 ])}
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] n_estimators=158, learning_rate=0.33 ............................
# [CV] ................... n_estimators=158, learning_rate=0.33 -   1.3s
# [CV] n_estimators=158, learning_rate=0.33 ............................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [CV] ................... n_estimators=158, learning_rate=0.33 -   1.3s
# [CV] n_estimators=158, learning_rate=0.33 ............................
# [CV] ................... n_estimators=158, learning_rate=0.33 -   1.1s
# [CV] n_estimators=158, learning_rate=0.33 ............................
# [CV] ................... n_estimators=158, learning_rate=0.33 -   1.7s
# [CV] n_estimators=158, learning_rate=0.33 ............................
# [CV] ................... n_estimators=158, learning_rate=0.33 -   1.1s
# [CV] n_estimators=161, learning_rate=0.33 ............................
# [CV] ................... n_estimators=161, learning_rate=0.33 -   1.7s
# [CV] n_estimators=161, learning_rate=0.33 ............................
# [CV] ................... n_estimators=161, learning_rate=0.33 -   1.0s
# [CV] n_estimators=161, learning_rate=0.33 ............................
# [CV] ................... n_estimators=161, learning_rate=0.33 -   1.3s
# [CV] n_estimators=161, learning_rate=0.33 ............................
# [CV] ................... n_estimators=161, learning_rate=0.33 -   1.0s
# [CV] n_estimators=161, learning_rate=0.33 ............................
# [CV] ................... n_estimators=161, learning_rate=0.33 -   1.3s
# [CV] n_estimators=164, learning_rate=0.33 ............................
# [CV] ................... n_estimators=164, learning_rate=0.33 -   1.6s
# [CV] n_estimators=164, learning_rate=0.33 ............................
# [CV] ................... n_estimators=164, learning_rate=0.33 -   1.1s
# [CV] n_estimators=164, learning_rate=0.33 ............................
# [CV] ................... n_estimators=164, learning_rate=0.33 -   1.6s
# [CV] n_estimators=164, learning_rate=0.33 ............................
# [CV] ................... n_estimators=164, learning_rate=0.33 -   1.2s
# [CV] n_estimators=164, learning_rate=0.33 ............................
# [CV] ................... n_estimators=164, learning_rate=0.33 -   1.1s
# [CV] n_estimators=168, learning_rate=0.33 ............................
# [CV] ................... n_estimators=168, learning_rate=0.33 -   1.4s
# [CV] n_estimators=168, learning_rate=0.33 ............................
# [CV] ................... n_estimators=168, learning_rate=0.33 -   1.1s
# [CV] n_estimators=168, learning_rate=0.33 ............................
# [CV] ................... n_estimators=168, learning_rate=0.33 -   1.3s
# [CV] n_estimators=168, learning_rate=0.33 ............................
# [CV] ................... n_estimators=168, learning_rate=0.33 -   1.1s
# [CV] n_estimators=168, learning_rate=0.33 ............................
# [CV] ................... n_estimators=168, learning_rate=0.33 -   1.4s
# [CV] n_estimators=171, learning_rate=0.33 ............................
# [CV] ................... n_estimators=171, learning_rate=0.33 -   1.7s
# [CV] n_estimators=171, learning_rate=0.33 ............................
# [CV] ................... n_estimators=171, learning_rate=0.33 -   1.3s
# [CV] n_estimators=171, learning_rate=0.33 ............................
# [CV] ................... n_estimators=171, learning_rate=0.33 -   1.1s
# [CV] n_estimators=171, learning_rate=0.33 ............................
# [CV] ................... n_estimators=171, learning_rate=0.33 -   1.3s
# [CV] n_estimators=171, learning_rate=0.33 ............................
# [CV] ................... n_estimators=171, learning_rate=0.33 -   1.2s
# [CV] n_estimators=174, learning_rate=0.33 ............................
# [CV] ................... n_estimators=174, learning_rate=0.33 -   1.3s
# [CV] n_estimators=174, learning_rate=0.33 ............................
# [CV] ................... n_estimators=174, learning_rate=0.33 -   1.1s
# [CV] n_estimators=174, learning_rate=0.33 ............................
# [CV] ................... n_estimators=174, learning_rate=0.33 -   1.3s
# [CV] n_estimators=174, learning_rate=0.33 ............................
# [CV] ................... n_estimators=174, learning_rate=0.33 -   1.2s
# [CV] n_estimators=174, learning_rate=0.33 ............................
# [CV] ................... n_estimators=174, learning_rate=0.33 -   1.4s
# [CV] n_estimators=158, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=158, learning_rate=0.334 -   1.1s
# [CV] n_estimators=158, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=158, learning_rate=0.334 -   1.1s
# [CV] n_estimators=158, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=158, learning_rate=0.334 -   1.1s
# [CV] n_estimators=158, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=158, learning_rate=0.334 -   1.4s
# [CV] n_estimators=158, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=158, learning_rate=0.334 -   1.1s
# [CV] n_estimators=161, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=161, learning_rate=0.334 -   1.2s
# [CV] n_estimators=161, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=161, learning_rate=0.334 -   1.3s
# [CV] n_estimators=161, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=161, learning_rate=0.334 -   1.2s
# [CV] n_estimators=161, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=161, learning_rate=0.334 -   1.0s
# [CV] n_estimators=161, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=161, learning_rate=0.334 -   1.2s
# [CV] n_estimators=164, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=164, learning_rate=0.334 -   1.1s
# [CV] n_estimators=164, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=164, learning_rate=0.334 -   1.4s
# [CV] n_estimators=164, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=164, learning_rate=0.334 -   1.2s
# [CV] n_estimators=164, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=164, learning_rate=0.334 -   1.1s
# [CV] n_estimators=164, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=164, learning_rate=0.334 -   1.2s
# [CV] n_estimators=168, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=168, learning_rate=0.334 -   1.1s
# [CV] n_estimators=168, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=168, learning_rate=0.334 -   1.3s
# [CV] n_estimators=168, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=168, learning_rate=0.334 -   1.2s
# [CV] n_estimators=168, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=168, learning_rate=0.334 -   1.3s
# [CV] n_estimators=168, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=168, learning_rate=0.334 -   1.5s
# [CV] n_estimators=171, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=171, learning_rate=0.334 -   1.3s
# [CV] n_estimators=171, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=171, learning_rate=0.334 -   1.5s
# [CV] n_estimators=171, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=171, learning_rate=0.334 -   1.3s
# [CV] n_estimators=171, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=171, learning_rate=0.334 -   1.6s
# [CV] n_estimators=171, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=171, learning_rate=0.334 -   1.2s
# [CV] n_estimators=174, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=174, learning_rate=0.334 -   1.5s
# [CV] n_estimators=174, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=174, learning_rate=0.334 -   1.4s
# [CV] n_estimators=174, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=174, learning_rate=0.334 -   1.3s
# [CV] n_estimators=174, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=174, learning_rate=0.334 -   1.6s
# [CV] n_estimators=174, learning_rate=0.334 ...........................
# [CV] .................. n_estimators=174, learning_rate=0.334 -   1.1s
# [CV] n_estimators=158, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=158, learning_rate=0.338 -   1.1s
# [CV] n_estimators=158, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=158, learning_rate=0.338 -   1.0s
# [CV] n_estimators=158, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=158, learning_rate=0.338 -   1.1s
# [CV] n_estimators=158, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=158, learning_rate=0.338 -   1.2s
# [CV] n_estimators=158, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=158, learning_rate=0.338 -   1.1s
# [CV] n_estimators=161, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=161, learning_rate=0.338 -   1.0s
# [CV] n_estimators=161, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=161, learning_rate=0.338 -   1.1s
# [CV] n_estimators=161, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=161, learning_rate=0.338 -   1.1s
# [CV] n_estimators=161, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=161, learning_rate=0.338 -   1.1s
# [CV] n_estimators=161, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=161, learning_rate=0.338 -   1.4s
# [CV] n_estimators=164, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=164, learning_rate=0.338 -   1.2s
# [CV] n_estimators=164, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=164, learning_rate=0.338 -   1.2s
# [CV] n_estimators=164, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=164, learning_rate=0.338 -   1.7s
# [CV] n_estimators=164, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=164, learning_rate=0.338 -   2.2s
# [CV] n_estimators=164, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=164, learning_rate=0.338 -   1.5s
# [CV] n_estimators=168, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=168, learning_rate=0.338 -   1.6s
# [CV] n_estimators=168, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=168, learning_rate=0.338 -   1.7s
# [CV] n_estimators=168, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=168, learning_rate=0.338 -   1.7s
# [CV] n_estimators=168, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=168, learning_rate=0.338 -   1.6s
# [CV] n_estimators=168, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=168, learning_rate=0.338 -   1.7s
# [CV] n_estimators=171, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=171, learning_rate=0.338 -   2.1s
# [CV] n_estimators=171, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=171, learning_rate=0.338 -   1.8s
# [CV] n_estimators=171, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=171, learning_rate=0.338 -   2.2s
# [CV] n_estimators=171, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=171, learning_rate=0.338 -   2.0s
# [CV] n_estimators=171, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=171, learning_rate=0.338 -   1.7s
# [CV] n_estimators=174, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=174, learning_rate=0.338 -   2.1s
# [CV] n_estimators=174, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=174, learning_rate=0.338 -   1.5s
# [CV] n_estimators=174, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=174, learning_rate=0.338 -   2.2s
# [CV] n_estimators=174, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=174, learning_rate=0.338 -   1.3s
# [CV] n_estimators=174, learning_rate=0.338 ...........................
# [CV] .................. n_estimators=174, learning_rate=0.338 -   1.4s
# [CV] n_estimators=158, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=158, learning_rate=0.342 -   1.0s
# [CV] n_estimators=158, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=158, learning_rate=0.342 -   1.2s
# [CV] n_estimators=158, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=158, learning_rate=0.342 -   1.2s
# [CV] n_estimators=158, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=158, learning_rate=0.342 -   1.0s
# [CV] n_estimators=158, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=158, learning_rate=0.342 -   1.1s
# [CV] n_estimators=161, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=161, learning_rate=0.342 -   1.2s
# [CV] n_estimators=161, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=161, learning_rate=0.342 -   1.3s
# [CV] n_estimators=161, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=161, learning_rate=0.342 -   1.1s
# [CV] n_estimators=161, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=161, learning_rate=0.342 -   1.1s
# [CV] n_estimators=161, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=161, learning_rate=0.342 -   1.2s
# [CV] n_estimators=164, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=164, learning_rate=0.342 -   1.1s
# [CV] n_estimators=164, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=164, learning_rate=0.342 -   1.4s
# [CV] n_estimators=164, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=164, learning_rate=0.342 -   1.2s
# [CV] n_estimators=164, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=164, learning_rate=0.342 -   1.1s
# [CV] n_estimators=164, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=164, learning_rate=0.342 -   1.1s
# [CV] n_estimators=168, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=168, learning_rate=0.342 -   1.1s
# [CV] n_estimators=168, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=168, learning_rate=0.342 -   1.2s
# [CV] n_estimators=168, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=168, learning_rate=0.342 -   1.1s
# [CV] n_estimators=168, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=168, learning_rate=0.342 -   1.1s
# [CV] n_estimators=168, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=168, learning_rate=0.342 -   1.1s
# [CV] n_estimators=171, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=171, learning_rate=0.342 -   1.1s
# [CV] n_estimators=171, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=171, learning_rate=0.342 -   1.1s
# [CV] n_estimators=171, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=171, learning_rate=0.342 -   1.1s
# [CV] n_estimators=171, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=171, learning_rate=0.342 -   1.1s
# [CV] n_estimators=171, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=171, learning_rate=0.342 -   1.7s
# [CV] n_estimators=174, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=174, learning_rate=0.342 -   1.4s
# [CV] n_estimators=174, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=174, learning_rate=0.342 -   1.6s
# [CV] n_estimators=174, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=174, learning_rate=0.342 -   1.3s
# [CV] n_estimators=174, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=174, learning_rate=0.342 -   1.1s
# [CV] n_estimators=174, learning_rate=0.342 ...........................
# [CV] .................. n_estimators=174, learning_rate=0.342 -   1.2s
# [CV] n_estimators=158, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=158, learning_rate=0.346 -   1.6s
# [CV] n_estimators=158, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=158, learning_rate=0.346 -   1.2s
# [CV] n_estimators=158, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=158, learning_rate=0.346 -   1.3s
# [CV] n_estimators=158, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=158, learning_rate=0.346 -   1.1s
# [CV] n_estimators=158, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=158, learning_rate=0.346 -   1.0s
# [CV] n_estimators=161, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=161, learning_rate=0.346 -   1.3s
# [CV] n_estimators=161, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=161, learning_rate=0.346 -   1.1s
# [CV] n_estimators=161, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=161, learning_rate=0.346 -   1.3s
# [CV] n_estimators=161, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=161, learning_rate=0.346 -   1.0s
# [CV] n_estimators=161, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=161, learning_rate=0.346 -   1.1s
# [CV] n_estimators=164, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=164, learning_rate=0.346 -   1.0s
# [CV] n_estimators=164, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=164, learning_rate=0.346 -   1.2s
# [CV] n_estimators=164, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=164, learning_rate=0.346 -   1.1s
# [CV] n_estimators=164, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=164, learning_rate=0.346 -   1.3s
# [CV] n_estimators=164, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=164, learning_rate=0.346 -   1.3s
# [CV] n_estimators=168, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=168, learning_rate=0.346 -   1.3s
# [CV] n_estimators=168, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=168, learning_rate=0.346 -   1.1s
# [CV] n_estimators=168, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=168, learning_rate=0.346 -   1.5s
# [CV] n_estimators=168, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=168, learning_rate=0.346 -   1.2s
# [CV] n_estimators=168, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=168, learning_rate=0.346 -   1.3s
# [CV] n_estimators=171, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=171, learning_rate=0.346 -   1.1s
# [CV] n_estimators=171, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=171, learning_rate=0.346 -   1.1s
# [CV] n_estimators=171, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=171, learning_rate=0.346 -   1.3s
# [CV] n_estimators=171, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=171, learning_rate=0.346 -   1.2s
# [CV] n_estimators=171, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=171, learning_rate=0.346 -   1.5s
# [CV] n_estimators=174, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=174, learning_rate=0.346 -   1.2s
# [CV] n_estimators=174, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=174, learning_rate=0.346 -   1.2s
# [CV] n_estimators=174, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=174, learning_rate=0.346 -   1.1s
# [CV] n_estimators=174, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=174, learning_rate=0.346 -   1.1s
# [CV] n_estimators=174, learning_rate=0.346 ...........................
# [CV] .................. n_estimators=174, learning_rate=0.346 -   1.5s
# [CV] n_estimators=158, learning_rate=0.35 ............................
# [CV] ................... n_estimators=158, learning_rate=0.35 -   1.2s
# [CV] n_estimators=158, learning_rate=0.35 ............................
# [CV] ................... n_estimators=158, learning_rate=0.35 -   1.0s
# [CV] n_estimators=158, learning_rate=0.35 ............................
# [CV] ................... n_estimators=158, learning_rate=0.35 -   1.3s
# [CV] n_estimators=158, learning_rate=0.35 ............................
# [CV] ................... n_estimators=158, learning_rate=0.35 -   1.4s
# [CV] n_estimators=158, learning_rate=0.35 ............................
# [CV] ................... n_estimators=158, learning_rate=0.35 -   1.1s
# [CV] n_estimators=161, learning_rate=0.35 ............................
# [CV] ................... n_estimators=161, learning_rate=0.35 -   1.2s
# [CV] n_estimators=161, learning_rate=0.35 ............................
# [CV] ................... n_estimators=161, learning_rate=0.35 -   1.1s
# [CV] n_estimators=161, learning_rate=0.35 ............................
# [CV] ................... n_estimators=161, learning_rate=0.35 -   1.5s
# [CV] n_estimators=161, learning_rate=0.35 ............................
# [CV] ................... n_estimators=161, learning_rate=0.35 -   1.1s
# [CV] n_estimators=161, learning_rate=0.35 ............................
# [CV] ................... n_estimators=161, learning_rate=0.35 -   1.6s
# [CV] n_estimators=164, learning_rate=0.35 ............................
# [CV] ................... n_estimators=164, learning_rate=0.35 -   1.1s
# [CV] n_estimators=164, learning_rate=0.35 ............................
# [CV] ................... n_estimators=164, learning_rate=0.35 -   1.2s
# [CV] n_estimators=164, learning_rate=0.35 ............................
# [CV] ................... n_estimators=164, learning_rate=0.35 -   1.4s
# [CV] n_estimators=164, learning_rate=0.35 ............................
# [CV] ................... n_estimators=164, learning_rate=0.35 -   1.5s
# [CV] n_estimators=164, learning_rate=0.35 ............................
# [CV] ................... n_estimators=164, learning_rate=0.35 -   1.4s
# [CV] n_estimators=168, learning_rate=0.35 ............................
# [CV] ................... n_estimators=168, learning_rate=0.35 -   1.3s
# [CV] n_estimators=168, learning_rate=0.35 ............................
# [CV] ................... n_estimators=168, learning_rate=0.35 -   1.1s
# [CV] n_estimators=168, learning_rate=0.35 ............................
# [CV] ................... n_estimators=168, learning_rate=0.35 -   1.2s
# [CV] n_estimators=168, learning_rate=0.35 ............................
# [CV] ................... n_estimators=168, learning_rate=0.35 -   1.1s
# [CV] n_estimators=168, learning_rate=0.35 ............................
# [CV] ................... n_estimators=168, learning_rate=0.35 -   1.3s
# [CV] n_estimators=171, learning_rate=0.35 ............................
# [CV] ................... n_estimators=171, learning_rate=0.35 -   1.5s
# [CV] n_estimators=171, learning_rate=0.35 ............................
# [CV] ................... n_estimators=171, learning_rate=0.35 -   1.3s
# [CV] n_estimators=171, learning_rate=0.35 ............................
# [CV] ................... n_estimators=171, learning_rate=0.35 -   1.2s
# [CV] n_estimators=171, learning_rate=0.35 ............................
# [CV] ................... n_estimators=171, learning_rate=0.35 -   1.3s
# [CV] n_estimators=171, learning_rate=0.35 ............................
# [CV] ................... n_estimators=171, learning_rate=0.35 -   1.1s
# [CV] n_estimators=174, learning_rate=0.35 ............................
# [CV] ................... n_estimators=174, learning_rate=0.35 -   1.3s
# [CV] n_estimators=174, learning_rate=0.35 ............................
# [CV] ................... n_estimators=174, learning_rate=0.35 -   1.3s
# [CV] n_estimators=174, learning_rate=0.35 ............................
# [CV] ................... n_estimators=174, learning_rate=0.35 -   1.2s
# [CV] n_estimators=174, learning_rate=0.35 ............................
# [CV] ................... n_estimators=174, learning_rate=0.35 -   1.5s
# [CV] n_estimators=174, learning_rate=0.35 ............................
# [CV] ................... n_estimators=174, learning_rate=0.35 -   1.5s
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed:  4.2min finished
# Report scores
# [mean: -1293233850.65259, std: 283061611.76795, params: {'n_estimators': 158, 'learning_rate': 0.33000000000000002}, mean: -1291529914.84791, std: 275190368.86414, params: {'n_estimators': 161, 'learning_rate': 0.33000000000000002}, mean: -1291621902.72431, std: 276432661.91969, params: {'n_estimators': 164, 'learning_rate': 0.33000000000000002}, mean: -1291869667.37033, std: 278434993.08017, params: {'n_estimators': 168, 'learning_rate': 0.33000000000000002}, mean: -1289890211.16179, std: 280525261.02336, params: {'n_estimators': 171, 'learning_rate': 0.33000000000000002}, mean: -1289197069.07641, std: 280708323.30905, params: {'n_estimators': 174, 'learning_rate': 0.33000000000000002}, mean: -1300151742.41748, std: 305339974.34615, params: {'n_estimators': 158, 'learning_rate': 0.33400000000000002}, mean: -1306129576.37077, std: 305633241.29177, params: {'n_estimators': 161, 'learning_rate': 0.33400000000000002}, mean: -1309813492.27055, std: 306077641.87939, params: {'n_estimators': 164, 'learning_rate': 0.33400000000000002}, mean: -1307994960.20509, std: 301600366.27498, params: {'n_estimators': 168, 'learning_rate': 0.33400000000000002}, mean: -1309206780.82419, std: 298167011.25862, params: {'n_estimators': 171, 'learning_rate': 0.33400000000000002}, mean: -1309729975.57256, std: 299342891.99764, params: {'n_estimators': 174, 'learning_rate': 0.33400000000000002}, mean: -1339792635.67937, std: 304848947.08462, params: {'n_estimators': 158, 'learning_rate': 0.33800000000000002}, mean: -1329702107.31337, std: 304941180.54467, params: {'n_estimators': 161, 'learning_rate': 0.33800000000000002}, mean: -1334142581.25959, std: 305331973.11425, params: {'n_estimators': 164, 'learning_rate': 0.33800000000000002}, mean: -1332499636.37127, std: 309089108.58833, params: {'n_estimators': 168, 'learning_rate': 0.33800000000000002}, mean: -1334720652.54084, std: 311346290.56660, params: {'n_estimators': 171, 'learning_rate': 0.33800000000000002}, mean: -1330018729.45265, std: 313218491.62633, params: {'n_estimators': 174, 'learning_rate': 0.33800000000000002}, mean: -1280775335.70882, std: 310398701.81871, params: {'n_estimators': 158, 'learning_rate': 0.34199999999999997}, mean: -1285086853.20087, std: 307445041.58985, params: {'n_estimators': 161, 'learning_rate': 0.34199999999999997}, mean: -1287283555.58598, std: 305977964.88527, params: {'n_estimators': 164, 'learning_rate': 0.34199999999999997}, mean: -1286972777.31065, std: 301350885.30679, params: {'n_estimators': 168, 'learning_rate': 0.34199999999999997}, mean: -1285124773.95621, std: 301695818.51297, params: {'n_estimators': 171, 'learning_rate': 0.34199999999999997}, mean: -1283058044.49344, std: 304953862.83229, params: {'n_estimators': 174, 'learning_rate': 0.34199999999999997}, mean: -1327752382.53860, std: 316507705.49209, params: {'n_estimators': 158, 'learning_rate': 0.34599999999999997}, mean: -1323327450.04382, std: 313689374.48917, params: {'n_estimators': 161, 'learning_rate': 0.34599999999999997}, mean: -1319289351.60691, std: 314315863.17181, params: {'n_estimators': 164, 'learning_rate': 0.34599999999999997}, mean: -1324045470.11545, std: 313095585.11630, params: {'n_estimators': 168, 'learning_rate': 0.34599999999999997}, mean: -1328467419.20267, std: 317188424.31325, params: {'n_estimators': 171, 'learning_rate': 0.34599999999999997}, mean: -1328218523.40807, std: 314651689.19700, params: {'n_estimators': 174, 'learning_rate': 0.34599999999999997}, mean: -1299113184.97183, std: 314549894.61030, params: {'n_estimators': 158, 'learning_rate': 0.34999999999999998}, mean: -1302263897.17766, std: 308263072.83663, params: {'n_estimators': 161, 'learning_rate': 0.34999999999999998}, mean: -1300205716.81334, std: 313077952.25213, params: {'n_estimators': 164, 'learning_rate': 0.34999999999999998}, mean: -1298315219.11699, std: 312088446.10119, params: {'n_estimators': 168, 'learning_rate': 0.34999999999999998}, mean: -1298138071.50148, std: 310299410.92306, params:  ...
# Report best params
# ('score:', -1280775335.7088168)
# learning_rate: 0.34199999999999997
# n_estimators: 158
# Params for best estimator are  {'n_estimators': 158, 'loss': 'exponential', 'base_estimator': None, 'random_state': 42, 'learning_rate': 0.34199999999999997}
# Now predict
# RMSE 0.212676917995
# Std:  70957.8704458  Mean:  186163.950317
# Min:  116438.661017  Max:  549588.689286
# Update param  n_estimators
# Best index is  0
# Arrived at start of search range  158
# Update param  learning_rate
# Best index is  3
# Params updated:  {'n_estimators': {'start': 158, 'end': 174, 'type': 'int'}, 'learning_rate': {'start': 0.33800000000000002, 'end': 0.34599999999999997, 'type': 'float'}}
# Go to next turn
